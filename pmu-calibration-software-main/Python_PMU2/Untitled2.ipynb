# %%
import numpy as np

array2 = np.array([-11.2271  , -10.0439  ,  -8.86104 ,  -7.67766 ,  -6.49476 ,
         -5.31176 ,  -4.12877 ,  -2.94577 ,  -1.76276 ,  -0.579739,
          0.603104,   1.78609 ,   2.96936 ,   4.15225 ,   5.33517 ,
          6.51809 ,   7.70096 ,   8.88447 ,  10.0672  ,  11.2502  ])

array1 = np.array([-11.13742447,  -9.96507394,  -8.7927234 ,  -7.62037287,
         -6.44802234,  -5.27567181,  -4.10332128,  -2.93097074,
         -1.75862021,  -0.58626968,   0.58608085,   1.75843138,
          2.93078192,   4.10313245,   5.27548298,   6.44783351,
          7.62018405,   8.79253458,   9.96488511,  11.13723564])

difference = array2 - array1

print("Difference between array2 and array1:")
print(difference)
# Out:
# Difference between array2 and array1:
# [-0.08967553 -0.07882606 -0.0683166  -0.05728713 -0.04673766 -0.03608819
#  -0.02544872 -0.01479926 -0.00413979  0.00653068  0.01702315  0.02765862
#   0.03857808  0.04911755  0.05968702  0.07025649  0.08077595  0.09193542
#   0.10231489  0.11296436]

# %%
import numpy as np

array2 = np.array([-11.242   , -10.0584  ,  -8.87509 ,  -7.69128 ,  -6.50791 ,
         -5.32446 ,  -4.14103 ,  -2.95762 ,  -1.77407 ,  -0.59072 ,
          0.592675,   1.77605 ,   2.95975 ,   4.14316 ,   5.32644 ,
          6.50987 ,   7.69317 ,   8.87702 ,  10.0604  ,  11.2438  ])

array1 = np.array([-11.13742447,  -9.96507394,  -8.7927234 ,  -7.62037287,
         -6.44802234,  -5.27567181,  -4.10332128,  -2.93097074,
         -1.75862021,  -0.58626968,   0.58608085,   1.75843138,
          2.93078192,   4.10313245,   5.27548298,   6.44783351,
          7.62018405,   8.79253458,   9.96488511,  11.13723564])

difference = array2 - array1

print("Difference between array2 and array1:")
print(difference)
# Out:
# Difference between array2 and array1:
# [-0.10457553 -0.09332606 -0.0823666  -0.07090713 -0.05988766 -0.04878819
#  -0.03770872 -0.02664926 -0.01544979 -0.00445032  0.00659415  0.01761862
#   0.02896808  0.04002755  0.05095702  0.06203649  0.07298595  0.08448542
#   0.09551489  0.10656436]

# %%
import numpy as np

array2 = np.array([-11.2187  , -10.0356  ,  -8.85281 ,  -7.66957 ,  -6.48681 ,
         -5.30391 ,  -4.12107 ,  -2.93817 ,  -1.75521 ,  -0.572433,
          0.610366,   1.79318 ,   2.97628 ,   4.15905 ,   5.34194 ,
          6.52472 ,   7.70751 ,   8.89058 ,  10.0735  ,  11.2564 ])

array1 = np.array([-11.13742447,  -9.96507394,  -8.7927234 ,  -7.62037287,
         -6.44802234,  -5.27567181,  -4.10332128,  -2.93097074,
         -1.75862021,  -0.58626968,   0.58608085,   1.75843138,
          2.93078192,   4.10313245,   5.27548298,   6.44783351,
          7.62018405,   8.79253458,   9.96488511,  11.13723564])

difference = array2 - array1

print("Difference between array2 and array1:")
print(difference)
# Out:
# Difference between array2 and array1:
# [-0.08127553 -0.07052606 -0.0600866  -0.04919713 -0.03878766 -0.02823819
#  -0.01774872 -0.00719926  0.00341021  0.01383668  0.02428515  0.03474862
#   0.04549808  0.05591755  0.06645702  0.07688649  0.08732595  0.09804542
#   0.10861489  0.11916436]

# %%
import numpy as np

array2 = np.array([-11.23    , -10.0467  ,  -8.86374 ,  -7.68025 ,  -6.49737 ,
         -5.31429 ,  -4.13124 ,  -2.9482  ,  -1.76505 ,  -0.582061,
          0.600872,   1.78392 ,   2.96721 ,   4.1502  ,   5.33322 ,
          6.51621 ,   7.6991  ,   8.88242 ,  10.0655  ,  11.2486 ])

array1 = np.array([-11.13742447,  -9.96507394,  -8.7927234 ,  -7.62037287,
         -6.44802234,  -5.27567181,  -4.10332128,  -2.93097074,
         -1.75862021,  -0.58626968,   0.58608085,   1.75843138,
          2.93078192,   4.10313245,   5.27548298,   6.44783351,
          7.62018405,   8.79253458,   9.96488511,  11.13723564])

difference = array2 - array1

print("Difference between array2 and array1:")
print(difference)
# Out:
# Difference between array2 and array1:
# [-0.09257553 -0.08162606 -0.0710166  -0.05987713 -0.04934766 -0.03861819
#  -0.02791872 -0.01722926 -0.00642979  0.00420868  0.01479115  0.02548862
#   0.03642808  0.04706755  0.05773702  0.06837649  0.07891595  0.08988542
#   0.10061489  0.11136436]
