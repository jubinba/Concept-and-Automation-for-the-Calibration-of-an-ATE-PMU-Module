# %%
from tqdm import tqdm

# %matplotlib notebook
from keithley2600 import Keithley2600
from pmu_som import pmu_ctrl, pmu_cal, pmu_calc, pmu_def
from time import sleep
import numpy as np
from matplotlib import pyplot as plt


try:
    del(p.c)
except:
    pass

k = Keithley2600('GPIB0::17::INSTR', visa_library='')
k.smua.reset()
k.smub.reset()

# p = communicator.communicator(False)
p = pmu_ctrl.pmu()

k.smua.measure.nplc = 3 # 0.001 to 25
k.smub.measure.nplc = 25 # 0.001 to 25

# k.smua.source.highc = k.smua.ENABLE
# k.smua.sense = k.smua.SENSE_REMOTE
k.smua.source.output = k.smua.OUTPUT_OFF
k.smub.source.output = k.smub.OUTPUT_OFF
k.display.screen = k.display.USER
k.display.clear()
k.display.settext("Ready to do $BStuff$N")
k.display.settext("ctrl from calibrate.ipynb")

k.beeper.enable = k.beeper.ON
k.play_chord(notes=("G5", "F5", "C5", "C5"), durations=0.1)
# k.beeper.enable = k.beeper.OFF

p.change_sys_ctrl({
    "DUTGND/CH" : 1,
    "INT10K"    : 1
})

# %%
zero_val = 0x4800

# offset_val = round(zero_val * 4.5 / 3.5)
offset_val = round(zero_val * 9 / 7)

print("Offset_value = 0x%04X" % (offset_val))
print("Min = %.3fV" % (pmu_calc.dac_to_v(0x0000, offset_val)))
print("1/4 = %.3fV" % (pmu_calc.dac_to_v(0x4000, offset_val)))
print("Mid = %.3fV" % (pmu_calc.dac_to_v(0x8000, offset_val)))
print("Max = %.3fV" % (pmu_calc.dac_to_v(0xFFFF, offset_val)))

for i in range(4):
    p.channels[i].write_dac(offset_val ,"Offset")
# Out:
# Offset_value = 0x5C92
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# d:\work\pmu_breakout\Software\Python_PMU2\calibrate.ipynb Zelle 2 line 7
#       <a href='vscode-notebook-cell:/d%3A/work/pmu_breakout/Software/Python_PMU2/calibrate.ipynb#W1sZmlsZQ%3D%3D?line=3'>4</a> offset_val = round(zero_val * 9 / 7)
#       <a href='vscode-notebook-cell:/d%3A/work/pmu_breakout/Software/Python_PMU2/calibrate.ipynb#W1sZmlsZQ%3D%3D?line=5'>6</a> print("Offset_value = 0x%04X" % (offset_val))
# ----> <a href='vscode-notebook-cell:/d%3A/work/pmu_breakout/Software/Python_PMU2/calibrate.ipynb#W1sZmlsZQ%3D%3D?line=6'>7</a> print("Min = %.3fV" % (pmu_calc.dac_to_v(0x0000, offset_val)))
#       <a href='vscode-notebook-cell:/d%3A/work/pmu_breakout/Software/Python_PMU2/calibrate.ipynb#W1sZmlsZQ%3D%3D?line=7'>8</a> print("1/4 = %.3fV" % (pmu_calc.dac_to_v(0x4000, offset_val)))
#       <a href='vscode-notebook-cell:/d%3A/work/pmu_breakout/Software/Python_PMU2/calibrate.ipynb#W1sZmlsZQ%3D%3D?line=8'>9</a> print("Mid = %.3fV" % (pmu_calc.dac_to_v(0x8000, offset_val)))
#
# NameError: name 'pmu_calc' is not defined

# %%
# set pmu-offset value
# new_offset_value = 0x5249

# read offset
for i in range(4):
    print("CH%i = 0x%X" % (i, p.channels[i].read_dac("Offset")))
# Out:
# CH0 = 0x5C92
# CH1 = 0x5C92
# CH2 = 0x5C92
# CH3 = 0x5C92

# %%
# pmu_cal.cal_FIN_I_C(p,k,0,"20u")
# pmu_cal.cal_FIN_I_M(p,k,0,"20u")
# cal_data = pmu_cal.calibrate(p,k,max_iterations=20,accuracy=1, wait_before_measure=0.5, reset_pmu=True)
cal_data = pmu_cal.calibrate(p,k,max_iterations=20,accuracy=0, wait_before_measure=2, reset_pmu=False)
# k.play_chord(notes=("F#5", "G#5", "A5", "B5", "C#5", "D5", "E5"), durations=0.1)
# p.reset()
# cal_data
# Out:
# FIN_U_M CALIBRATION for channel 0
# 	NEW_FIN_M = FIN_U_M * (V_HIGH_SET / V_HIGH_MEAS)
# 	64800 = 65535 * (16.010 V / 16.192 V)
# 	V_MAX after Cal = 15.935 V
# FIN_U_C CALIBRATION for channel 0
# 	NEW_FIN_C = FIN_C - (Zero_offset / LSB)
# 	32940 = 32768 - (-58.579 mV / 339.890 µV)
# 	Offset after Cal = 458.057 µV
# FIN_U_M CALIBRATION for channel 0
# 	NEW_FIN_M = FIN_U_M * (V_HIGH_SET / V_HIGH_MEAS)
# 	64847 = 64800 * (16.010 V / 15.998 V)
# 	V_MAX after Cal = 16.010 V
# FIN_U_C CALIBRATION for channel 0
# 	NEW_FIN_C = FIN_C - (Zero_offset / LSB)
# 	32926 = 32940 - (4.921 mV / 339.890 µV)
# 	Offset after Cal = 117.030 µV
# FIN_U_M CALIBRATION for channel 0
# 	NEW_FIN_M = FIN_U_M * (V_HIGH_SET / V_HIGH_MEAS)
# 	64852 = 64846 * (16.010 V / 16.008 V)
# 	V_MAX after Cal = 16.007 V
# FIN_U_C CALIBRATION for channel 0
# 	NEW_FIN_C = FIN_C - (Zero_offset / LSB)
# 	32924 = 32926 - (715.118 µV / 339.890 µV)
# 	Offset after Cal = 37.177 µV
# FIN_U_M CALIBRATION for channel 0
# 	NEW_FIN_M = FIN_U_M * (V_HIGH_SET / V_HIGH_MEAS)
# 	64850 = 64852 * (16.010 V / 16.010 V)
# 	V_MAX after Cal = 16.006 V
# FIN_U_C CALIBRATION for channel 0
# 	NEW_FIN_C = FIN_C - (Zero_offset / LSB)
# 	32925 = 32924 - (-230.248 µV / 339.890 µV)
# 	Offset after Cal = 116.801 µV
# FIN_U_M CALIBRATION for channel 0
# 	NEW_FIN_M = FIN_U_M * (V_HIGH_SET / V_HIGH_MEAS)
# 	64852 = 64850 * (16.010 V / 16.009 V)
# 	V_MAX after Cal = 16.007 V
# FIN_U_C CALIBRATION for channel 0
# 	NEW_FIN_C = FIN_C - (Zero_offset / LSB)
# 	32924 = 32925 - (362.878 µV / 339.890 µV)
# 	Offset after Cal = 22.552 µV
# FIN_U_M CALIBRATION for channel 0
# 	NEW_FIN_M = FIN_U_M * (V_HIGH_SET / V_HIGH_MEAS)
# 	64851 = 64852 * (16.010 V / 16.010 V)
# 	V_MAX after Cal = 16.006 V
# FIN_U_C CALIBRATION for channel 0
# 	NEW_FIN_C = FIN_C - (Zero_offset / LSB)
# 	32925 = 32924 - (-225.780 µV / 339.890 µV)
# 	Offset after Cal = 114.174 µV
# FIN_U_M CALIBRATION for channel 0
# 	NEW_FIN_M = FIN_U_M * (V_HIGH_SET / V_HIGH_MEAS)
# 	64852 = 64850 * (16.010 V / 16.010 V)
# 	V_MAX after Cal = 16.007 V
# FIN_U_C CALIBRATION for channel 0
# 	NEW_FIN_C = FIN_C - (Zero_offset / LSB)
# 	32924 = 32925 - (365.608 µV / 339.890 µV)
# 	Offset after Cal = 19.734 µV
# FIN_U_M CALIBRATION for channel 0
# 	NEW_FIN_M = FIN_U_M * (V_HIGH_SET / V_HIGH_MEAS)
# 	64852 = 64852 * (16.010 V / 16.010 V)
# 	V_MAX after Cal = 16.007 V
# FIN_U_C CALIBRATION for channel 0
# 	NEW_FIN_C = FIN_C - (Zero_offset / LSB)
# 	32924 = 32924 - (25.511 µV / 339.890 µV)
# 	Offset after Cal = 18.358 µV
# Calibration OK
# FIN_U_M CALIBRATION for channel 1
# 	NEW_FIN_M = FIN_U_M * (V_HIGH_SET / V_HIGH_MEAS)
# 	64842 = 65535 * (16.010 V / 16.181 V)
# 	V_MAX after Cal = 15.939 V
# FIN_U_C CALIBRATION for channel 1
# 	NEW_FIN_C = FIN_C - (Zero_offset / LSB)
# 	32953 = 32768 - (-62.973 mV / 339.890 µV)
# 	Offset after Cal = 637.038 µV
# FIN_U_M CALIBRATION for channel 1
# 	NEW_FIN_M = FIN_U_M * (V_HIGH_SET / V_HIGH_MEAS)
# 	64858 = 64842 * (16.010 V / 16.006 V)
# 	V_MAX after Cal = 16.008 V
# FIN_U_C CALIBRATION for channel 1
# 	NEW_FIN_C = FIN_C - (Zero_offset / LSB)
# 	32947 = 32953 - (2.170 mV / 339.890 µV)
# 	Offset after Cal = 113.356 µV
# FIN_U_M CALIBRATION for channel 1
# 	NEW_FIN_M = FIN_U_M * (V_HIGH_SET / V_HIGH_MEAS)
# 	64859 = 64858 * (16.010 V / 16.010 V)
# 	V_MAX after Cal = 16.006 V
# FIN_U_C CALIBRATION for channel 1
# 	NEW_FIN_C = FIN_C - (Zero_offset / LSB)
# 	32947 = 32947 - (113.869 µV / 339.890 µV)
# 	Offset after Cal = 120.642 µV
# FIN_U_M CALIBRATION for channel 1
# 	NEW_FIN_M = FIN_U_M * (V_HIGH_SET / V_HIGH_MEAS)
# 	64860 = 64858 * (16.010 V / 16.009 V)
# 	V_MAX after Cal = 16.007 V
# FIN_U_C CALIBRATION for channel 1
# 	NEW_FIN_C = FIN_C - (Zero_offset / LSB)
# 	32946 = 32947 - (273.058 µV / 339.890 µV)
# 	Offset after Cal = -65.401 µV
# FIN_U_M CALIBRATION for channel 1
# 	NEW_FIN_M = FIN_U_M * (V_HIGH_SET / V_HIGH_MEAS)
# 	64860 = 64860 * (16.010 V / 16.010 V)
# 	V_MAX after Cal = 16.007 V
# FIN_U_C CALIBRATION for channel 1
# 	NEW_FIN_C = FIN_C - (Zero_offset / LSB)
# 	32946 = 32946 - (-58.694 µV / 339.890 µV)
# 	Offset after Cal = -69.218 µV
# Calibration OK
# FIN_U_M CALIBRATION for channel 2
# 	NEW_FIN_M = FIN_U_M * (V_HIGH_SET / V_HIGH_MEAS)
# 	64828 = 65535 * (16.010 V / 16.184 V)
# 	V_MAX after Cal = 15.938 V
# FIN_U_C CALIBRATION for channel 2
# 	NEW_FIN_C = FIN_C - (Zero_offset / LSB)
# 	32948 = 32768 - (-61.166 mV / 339.890 µV)
# 	Offset after Cal = 638.306 µV
# FIN_U_M CALIBRATION for channel 2
# 	NEW_FIN_M = FIN_U_M * (V_HIGH_SET / V_HIGH_MEAS)
# 	64855 = 64828 * (16.010 V / 16.003 V)
# 	V_MAX after Cal = 16.009 V
# FIN_U_C CALIBRATION for channel 2
# 	NEW_FIN_C = FIN_C - (Zero_offset / LSB)
# 	32939 = 32948 - (3.156 mV / 339.890 µV)
# 	Offset after Cal = 43.793 µV
# FIN_U_M CALIBRATION for channel 2
# 	NEW_FIN_M = FIN_U_M * (V_HIGH_SET / V_HIGH_MEAS)
# 	64857 = 64854 * (16.010 V / 16.009 V)
# 	V_MAX after Cal = 16.006 V
# FIN_U_C CALIBRATION for channel 2
# 	NEW_FIN_C = FIN_C - (Zero_offset / LSB)
# 	32938 = 32939 - (221.110 µV / 339.890 µV)
# 	Offset after Cal = -133.915 µV
# FIN_U_M CALIBRATION for channel 2
# 	NEW_FIN_M = FIN_U_M * (V_HIGH_SET / V_HIGH_MEAS)
# 	64860 = 64856 * (16.010 V / 16.009 V)
# 	V_MAX after Cal = 16.007 V
# FIN_U_C CALIBRATION for channel 2
# 	NEW_FIN_C = FIN_C - (Zero_offset / LSB)
# 	32937 = 32938 - (300.338 µV / 339.890 µV)
# 	Offset after Cal = -56.980 µV
# FIN_U_M CALIBRATION for channel 2
# 	NEW_FIN_M = FIN_U_M * (V_HIGH_SET / V_HIGH_MEAS)
# 	64858 = 64860 * (16.010 V / 16.010 V)
# 	V_MAX after Cal = 16.006 V
# FIN_U_C CALIBRATION for channel 2
# 	NEW_FIN_C = FIN_C - (Zero_offset / LSB)
# 	32938 = 32937 - (-308.929 µV / 339.890 µV)
# 	Offset after Cal = 32.575 µV
# FIN_U_M CALIBRATION for channel 2
# 	NEW_FIN_M = FIN_U_M * (V_HIGH_SET / V_HIGH_MEAS)
# 	64859 = 64858 * (16.010 V / 16.010 V)
# 	V_MAX after Cal = 16.007 V
# FIN_U_C CALIBRATION for channel 2
# 	NEW_FIN_C = FIN_C - (Zero_offset / LSB)
# 	32938 = 32938 - (31.316 µV / 339.890 µV)
# 	Offset after Cal = 26.243 µV
# FIN_U_M CALIBRATION for channel 2
# 	NEW_FIN_M = FIN_U_M * (V_HIGH_SET / V_HIGH_MEAS)
# 	64857 = 64858 * (16.010 V / 16.010 V)
# 	V_MAX after Cal = 16.006 V
# FIN_U_C CALIBRATION for channel 2
# 	NEW_FIN_C = FIN_C - (Zero_offset / LSB)
# 	32938 = 32938 - (-134.742 µV / 339.890 µV)
# 	Offset after Cal = -120.673 µV
# FIN_U_M CALIBRATION for channel 2
# 	NEW_FIN_M = FIN_U_M * (V_HIGH_SET / V_HIGH_MEAS)
# 	64857 = 64856 * (16.010 V / 16.010 V)
# 	V_MAX after Cal = 16.006 V
# FIN_U_C CALIBRATION for channel 2
# 	NEW_FIN_C = FIN_C - (Zero_offset / LSB)
# 	32938 = 32938 - (-123.882 µV / 339.890 µV)
# 	Offset after Cal = -124.979 µV
# Calibration OK
# FIN_U_M CALIBRATION for channel 3
# 	NEW_FIN_M = FIN_U_M * (V_HIGH_SET / V_HIGH_MEAS)
# 	64791 = 65535 * (16.010 V / 16.194 V)
# 	V_MAX after Cal = 15.934 V
# FIN_U_C CALIBRATION for channel 3
# 	NEW_FIN_C = FIN_C - (Zero_offset / LSB)
# 	32933 = 32768 - (-56.151 mV / 339.890 µV)
# 	Offset after Cal = 508.068 µV
# FIN_U_M CALIBRATION for channel 3
# 	NEW_FIN_M = FIN_U_M * (V_HIGH_SET / V_HIGH_MEAS)
# 	64855 = 64790 * (16.010 V / 15.994 V)
# 	V_MAX after Cal = 16.012 V
# FIN_U_C CALIBRATION for channel 3
# 	NEW_FIN_C = FIN_C - (Zero_offset / LSB)
# 	32913 = 32933 - (6.679 mV / 339.890 µV)
# 	Offset after Cal = -185.215 µV
# FIN_U_M CALIBRATION for channel 3
# 	NEW_FIN_M = FIN_U_M * (V_HIGH_SET / V_HIGH_MEAS)
# 	64857 = 64854 * (16.010 V / 16.009 V)
# 	V_MAX after Cal = 16.006 V
# FIN_U_C CALIBRATION for channel 3
# 	NEW_FIN_C = FIN_C - (Zero_offset / LSB)
# 	32913 = 32913 - (-9.198 µV / 339.890 µV)
# 	Offset after Cal = -18.139 µV
# FIN_U_M CALIBRATION for channel 3
# 	NEW_FIN_M = FIN_U_M * (V_HIGH_SET / V_HIGH_MEAS)
# 	64858 = 64856 * (16.010 V / 16.009 V)
# 	V_MAX after Cal = 16.007 V
# FIN_U_C CALIBRATION for channel 3
# 	NEW_FIN_C = FIN_C - (Zero_offset / LSB)
# 	32913 = 32913 - (148.678 µV / 339.890 µV)
# 	Offset after Cal = 135.112 µV
# FIN_U_M CALIBRATION for channel 3
# 	NEW_FIN_M = FIN_U_M * (V_HIGH_SET / V_HIGH_MEAS)
# 	64857 = 64858 * (16.010 V / 16.010 V)
# 	V_MAX after Cal = 16.006 V
# FIN_U_C CALIBRATION for channel 3
# 	NEW_FIN_C = FIN_C - (Zero_offset / LSB)
# 	32913 = 32913 - (-2.835 µV / 339.890 µV)
# 	Offset after Cal = -2.122 µV
# FIN_U_M CALIBRATION for channel 3
# 	NEW_FIN_M = FIN_U_M * (V_HIGH_SET / V_HIGH_MEAS)
# 	64857 = 64856 * (16.010 V / 16.010 V)
# 	V_MAX after Cal = 16.006 V
# FIN_U_C CALIBRATION for channel 3
# 	NEW_FIN_C = FIN_C - (Zero_offset / LSB)
# 	32913 = 32913 - (-18.086 µV / 339.890 µV)
# 	Offset after Cal = -23.932 µV
# Calibration OK
# FIN_I_M CALIBRATION for channel 0 @ 5uA
# 	NEW_FIN_I_M = FIN_I_M * (I_HIGH_SET / I_HIGH_MEAS)
# 	64671 = 65535 * (5.569 µA / 5.643 µA)
# 	V_MAX after Cal = 5.494 µA
# FIN_I_C CALIBRATION for channel 0 @ 5uA
# 	NEW_FIN_C = FIN_C - (Zero_offset / LSB)
# 	33211 = 32768 - (-75.286 nA / 169.945 pA)
# 	Offset after Cal = 969.887 pA
# FIN_I_M CALIBRATION for channel 0 @ 5uA
# 	NEW_FIN_I_M = FIN_I_M * (I_HIGH_SET / I_HIGH_MEAS)
# 	64654 = 64670 * (5.569 µA / 5.570 µA)
# 	V_MAX after Cal = 5.567 µA
# FIN_I_C CALIBRATION for channel 0 @ 5uA
# 	NEW_FIN_C = FIN_C - (Zero_offset / LSB)
# 	33214 = 33211 - (-527.382 pA / 169.945 pA)
# 	Offset after Cal = -60.320 pA
# FIN_I_M CALIBRATION for channel 0 @ 5uA
# 	NEW_FIN_I_M = FIN_I_M * (I_HIGH_SET / I_HIGH_MEAS)
# 	64666 = 64654 * (5.569 µA / 5.568 µA)
# 	V_MAX after Cal = 5.570 µA
# FIN_I_C CALIBRATION for channel 0 @ 5uA
# 	NEW_FIN_C = FIN_C - (Zero_offset / LSB)
# 	33209 = 33214 - (931.740 pA / 169.945 pA)
# 	Offset after Cal = 7.868 pA
# FIN_I_M CALIBRATION for channel 0 @ 5uA
# 	NEW_FIN_I_M = FIN_I_M * (I_HIGH_SET / I_HIGH_MEAS)
# 	64665 = 64666 * (5.569 µA / 5.569 µA)
# 	V_MAX after Cal = 5.568 µA
# FIN_I_C CALIBRATION for channel 0 @ 5uA
# 	NEW_FIN_C = FIN_C - (Zero_offset / LSB)
# 	33210 = 33209 - (-226.021 pA / 169.945 pA)
# 	Offset after Cal = -104.904 pA
# FIN_I_M CALIBRATION for channel 0 @ 5uA
# 	NEW_FIN_I_M = FIN_I_M * (I_HIGH_SET / I_HIGH_MEAS)
# 	64667 = 64664 * (5.569 µA / 5.568 µA)
# 	V_MAX after Cal = 5.569 µA
# FIN_I_C CALIBRATION for channel 0 @ 5uA
# 	NEW_FIN_C = FIN_C - (Zero_offset / LSB)
# 	33209 = 33210 - (85.354 pA / 169.945 pA)
# 	Offset after Cal = -122.070 pA
# FIN_I_M CALIBRATION for channel 0 @ 5uA
# 	NEW_FIN_I_M = FIN_I_M * (I_HIGH_SET / I_HIGH_MEAS)
# 	64667 = 64666 * (5.569 µA / 5.569 µA)
# 	V_MAX after Cal = 5.569 µA
# FIN_I_C CALIBRATION for channel 0 @ 5uA
# 	NEW_FIN_C = FIN_C - (Zero_offset / LSB)
# 	33210 = 33209 - (-132.561 pA / 169.945 pA)
# 	Offset after Cal = 9.298 pA
# FIN_I_M CALIBRATION for channel 0 @ 5uA
# 	NEW_FIN_I_M = FIN_I_M * (I_HIGH_SET / I_HIGH_MEAS)
# 	64665 = 64666 * (5.569 µA / 5.569 µA)
# 	V_MAX after Cal = 5.568 µA
# FIN_I_C CALIBRATION for channel 0 @ 5uA
# 	NEW_FIN_C = FIN_C - (Zero_offset / LSB)
# 	33211 = 33210 - (-169.516 pA / 169.945 pA)
# 	Offset after Cal = -26.464 pA
# FIN_I_M CALIBRATION for channel 0 @ 5uA
# 	NEW_FIN_I_M = FIN_I_M * (I_HIGH_SET / I_HIGH_MEAS)
# 	64666 = 64664 * (5.569 µA / 5.568 µA)
# 	V_MAX after Cal = 5.569 µA
# FIN_I_C CALIBRATION for channel 0 @ 5uA
# 	NEW_FIN_C = FIN_C - (Zero_offset / LSB)
# 	33210 = 33211 - (159.502 pA / 169.945 pA)
# 	Offset after Cal = -37.193 pA
# FIN_I_M CALIBRATION for channel 0 @ 5uA
# 	NEW_FIN_I_M = FIN_I_M * (I_HIGH_SET / I_HIGH_MEAS)
# 	64666 = 64666 * (5.569 µA / 5.569 µA)
# 	V_MAX after Cal = 5.569 µA
# FIN_I_C CALIBRATION for channel 0 @ 5uA
# 	NEW_FIN_C = FIN_C - (Zero_offset / LSB)
# 	33210 = 33210 - (-31.233 pA / 169.945 pA)
# 	Offset after Cal = -56.505 pA
# Calibration OK
# FIN_I_M CALIBRATION for channel 1 @ 5uA
# 	NEW_FIN_I_M = FIN_I_M * (I_HIGH_SET / I_HIGH_MEAS)
# 	64645 = 65535 * (5.569 µA / 5.645 µA)
# 	V_MAX after Cal = 5.492 µA
# FIN_I_C CALIBRATION for channel 1 @ 5uA
# 	NEW_FIN_C = FIN_C - (Zero_offset / LSB)
# 	33220 = 32768 - (-76.815 nA / 169.945 pA)
# 	Offset after Cal = 1.031 nA
# FIN_I_M CALIBRATION for channel 1 @ 5uA
# 	NEW_FIN_I_M = FIN_I_M * (I_HIGH_SET / I_HIGH_MEAS)
# 	64634 = 64644 * (5.569 µA / 5.569 µA)
# 	V_MAX after Cal = 5.568 µA
# FIN_I_C CALIBRATION for channel 1 @ 5uA
# 	NEW_FIN_C = FIN_C - (Zero_offset / LSB)
# 	33219 = 33220 - (195.503 pA / 169.945 pA)
# 	Offset after Cal = -953.690 fA
# FIN_I_M CALIBRATION for channel 1 @ 5uA
# 	NEW_FIN_I_M = FIN_I_M * (I_HIGH_SET / I_HIGH_MEAS)
# 	64646 = 64634 * (5.569 µA / 5.568 µA)
# 	V_MAX after Cal = 5.570 µA
# FIN_I_C CALIBRATION for channel 1 @ 5uA
# 	NEW_FIN_C = FIN_C - (Zero_offset / LSB)
# 	33213 = 33219 - (1.071 nA / 169.945 pA)
# 	Offset after Cal = -5.960 pA
# FIN_I_M CALIBRATION for channel 1 @ 5uA
# 	NEW_FIN_I_M = FIN_I_M * (I_HIGH_SET / I_HIGH_MEAS)
# 	64647 = 64646 * (5.569 µA / 5.569 µA)
# 	V_MAX after Cal = 5.569 µA
# FIN_I_C CALIBRATION for channel 1 @ 5uA
# 	NEW_FIN_C = FIN_C - (Zero_offset / LSB)
# 	33213 = 33213 - (-20.504 pA / 169.945 pA)
# 	Offset after Cal = -43.869 pA
# FIN_I_M CALIBRATION for channel 1 @ 5uA
# 	NEW_FIN_I_M = FIN_I_M * (I_HIGH_SET / I_HIGH_MEAS)
# 	64647 = 64646 * (5.569 µA / 5.569 µA)
# 	V_MAX after Cal = 5.568 µA
# FIN_I_C CALIBRATION for channel 1 @ 5uA
# 	NEW_FIN_C = FIN_C - (Zero_offset / LSB)
# 	33213 = 33213 - (3.815 pA / 169.945 pA)
# 	Offset after Cal = -25.988 pA
# Calibration OK
# FIN_I_M CALIBRATION for channel 2 @ 5uA
# 	NEW_FIN_I_M = FIN_I_M * (I_HIGH_SET / I_HIGH_MEAS)
# 	64770 = 65535 * (5.569 µA / 5.634 µA)
# 	V_MAX after Cal = 5.502 µA
# FIN_I_C CALIBRATION for channel 2 @ 5uA
# 	NEW_FIN_C = FIN_C - (Zero_offset / LSB)
# 	33197 = 32768 - (-72.976 nA / 169.945 pA)
# 	Offset after Cal = 912.428 pA
# FIN_I_M CALIBRATION for channel 2 @ 5uA
# 	NEW_FIN_I_M = FIN_I_M * (I_HIGH_SET / I_HIGH_MEAS)
# 	64680 = 64770 * (5.569 µA / 5.576 µA)
# 	V_MAX after Cal = 5.561 µA
# FIN_I_C CALIBRATION for channel 2 @ 5uA
# 	NEW_FIN_C = FIN_C - (Zero_offset / LSB)
# 	33237 = 33197 - (-6.853 nA / 169.945 pA)
# 	Offset after Cal = 18.835 pA
# FIN_I_M CALIBRATION for channel 2 @ 5uA
# 	NEW_FIN_I_M = FIN_I_M * (I_HIGH_SET / I_HIGH_MEAS)
# 	64690 = 64680 * (5.569 µA / 5.568 µA)
# 	V_MAX after Cal = 5.569 µA
# FIN_I_C CALIBRATION for channel 2 @ 5uA
# 	NEW_FIN_C = FIN_C - (Zero_offset / LSB)
# 	33232 = 33237 - (913.143 pA / 169.945 pA)
# 	Offset after Cal = 15.020 pA
# FIN_I_M CALIBRATION for channel 2 @ 5uA
# 	NEW_FIN_I_M = FIN_I_M * (I_HIGH_SET / I_HIGH_MEAS)
# 	64690 = 64690 * (5.569 µA / 5.569 µA)
# 	V_MAX after Cal = 5.569 µA
# FIN_I_C CALIBRATION for channel 2 @ 5uA
# 	NEW_FIN_C = FIN_C - (Zero_offset / LSB)
# 	33232 = 33232 - (52.691 pA / 169.945 pA)
# 	Offset after Cal = 28.372 pA
# Calibration OK
# FIN_I_M CALIBRATION for channel 3 @ 5uA
# 	NEW_FIN_I_M = FIN_I_M * (I_HIGH_SET / I_HIGH_MEAS)
# 	64672 = 65535 * (5.569 µA / 5.643 µA)
# 	V_MAX after Cal = 5.494 µA
# FIN_I_C CALIBRATION for channel 3 @ 5uA
# 	NEW_FIN_C = FIN_C - (Zero_offset / LSB)
# 	33220 = 32768 - (-76.798 nA / 169.945 pA)
# 	Offset after Cal = 1.082 nA
# FIN_I_M CALIBRATION for channel 3 @ 5uA
# 	NEW_FIN_I_M = FIN_I_M * (I_HIGH_SET / I_HIGH_MEAS)
# 	64634 = 64672 * (5.569 µA / 5.572 µA)
# 	V_MAX after Cal = 5.565 µA
# FIN_I_C CALIBRATION for channel 3 @ 5uA
# 	NEW_FIN_C = FIN_C - (Zero_offset / LSB)
# 	33233 = 33220 - (-2.165 nA / 169.945 pA)
# 	Offset after Cal = 58.413 pA
# FIN_I_M CALIBRATION for channel 3 @ 5uA
# 	NEW_FIN_I_M = FIN_I_M * (I_HIGH_SET / I_HIGH_MEAS)
# 	64646 = 64634 * (5.569 µA / 5.568 µA)
# 	V_MAX after Cal = 5.570 µA
# FIN_I_C CALIBRATION for channel 3 @ 5uA
# 	NEW_FIN_C = FIN_C - (Zero_offset / LSB)
# 	33226 = 33233 - (1.110 nA / 169.945 pA)
# 	Offset after Cal = -118.494 pA
# FIN_I_M CALIBRATION for channel 3 @ 5uA
# 	NEW_FIN_I_M = FIN_I_M * (I_HIGH_SET / I_HIGH_MEAS)
# 	64648 = 64646 * (5.569 µA / 5.568 µA)
# 	V_MAX after Cal = 5.569 µA
# FIN_I_C CALIBRATION for channel 3 @ 5uA
# 	NEW_FIN_C = FIN_C - (Zero_offset / LSB)
# 	33226 = 33226 - (51.022 pA / 169.945 pA)
# 	Offset after Cal = 14.544 pA
# FIN_I_M CALIBRATION for channel 3 @ 5uA
# 	NEW_FIN_I_M = FIN_I_M * (I_HIGH_SET / I_HIGH_MEAS)
# 	64647 = 64648 * (5.569 µA / 5.569 µA)
# 	V_MAX after Cal = 5.568 µA
# FIN_I_C CALIBRATION for channel 3 @ 5uA
# 	NEW_FIN_C = FIN_C - (Zero_offset / LSB)
# 	33227 = 33226 - (-94.414 pA / 169.945 pA)
# 	Offset after Cal = 41.008 pA
# FIN_I_M CALIBRATION for channel 3 @ 5uA
# 	NEW_FIN_I_M = FIN_I_M * (I_HIGH_SET / I_HIGH_MEAS)
# 	64646 = 64646 * (5.569 µA / 5.569 µA)
# 	V_MAX after Cal = 5.569 µA
# FIN_I_C CALIBRATION for channel 3 @ 5uA
# 	NEW_FIN_C = FIN_C - (Zero_offset / LSB)
# 	33227 = 33227 - (79.870 pA / 169.945 pA)
# 	Offset after Cal = 35.763 pA
# FIN_I_M CALIBRATION for channel 3 @ 5uA
# 	NEW_FIN_I_M = FIN_I_M * (I_HIGH_SET / I_HIGH_MEAS)
# 	64647 = 64646 * (5.569 µA / 5.569 µA)
# 	V_MAX after Cal = 5.569 µA
# FIN_I_C CALIBRATION for channel 3 @ 5uA
# 	NEW_FIN_C = FIN_C - (Zero_offset / LSB)
# 	33227 = 33227 - (51.260 pA / 169.945 pA)
# 	Offset after Cal = 27.180 pA
# FIN_I_M CALIBRATION for channel 3 @ 5uA
# 	NEW_FIN_I_M = FIN_I_M * (I_HIGH_SET / I_HIGH_MEAS)
# 	64647 = 64646 * (5.569 µA / 5.569 µA)
# 	V_MAX after Cal = 5.569 µA
# FIN_I_C CALIBRATION for channel 3 @ 5uA
# 	NEW_FIN_C = FIN_C - (Zero_offset / LSB)
# 	33227 = 33227 - (43.154 pA / 169.945 pA)
# 	Offset after Cal = 15.736 pA
# Calibration OK
# FIN_I_M CALIBRATION for channel 0 @ 20uA
# 	NEW_FIN_I_M = FIN_I_M * (I_HIGH_SET / I_HIGH_MEAS)
# 	64701 = 65535 * (22.274 µA / 22.562 µA)
# 	V_MAX after Cal = 21.980 µA
# FIN_I_C CALIBRATION for channel 0 @ 20uA
# 	NEW_FIN_C = FIN_C - (Zero_offset / LSB)
# 	33181 = 32768 - (-280.883 nA / 679.779 pA)
# 	Offset after Cal = 4.094 nA
# FIN_I_M CALIBRATION for channel 0 @ 20uA
# 	NEW_FIN_I_M = FIN_I_M * (I_HIGH_SET / I_HIGH_MEAS)
# 	64727 = 64700 * (22.274 µA / 22.265 µA)
# 	V_MAX after Cal = 22.283 µA
# FIN_I_C CALIBRATION for channel 0 @ 20uA
# 	NEW_FIN_C = FIN_C - (Zero_offset / LSB)
# 	33161 = 33181 - (13.328 nA / 679.779 pA)
# 	Offset after Cal = -474.453 pA
# FIN_I_M CALIBRATION for channel 0 @ 20uA
# 	NEW_FIN_I_M = FIN_I_M * (I_HIGH_SET / I_HIGH_MEAS)
# 	64742 = 64726 * (22.274 µA / 22.269 µA)
# 	V_MAX after Cal = 22.280 µA
# FIN_I_C CALIBRATION for channel 0 @ 20uA
# 	NEW_FIN_C = FIN_C - (Zero_offset / LSB)
# 	33153 = 33161 - (5.348 nA / 679.779 pA)
# 	Offset after Cal = -934.600 pA
# FIN_I_M CALIBRATION for channel 0 @ 20uA
# 	NEW_FIN_I_M = FIN_I_M * (I_HIGH_SET / I_HIGH_MEAS)
# 	64741 = 64742 * (22.274 µA / 22.275 µA)
# 	V_MAX after Cal = 22.273 µA
# FIN_I_C CALIBRATION for channel 0 @ 20uA
# 	NEW_FIN_C = FIN_C - (Zero_offset / LSB)
# 	33155 = 33153 - (-1.485 nA / 679.779 pA)
# 	Offset after Cal = -579.357 pA
# FIN_I_M CALIBRATION for channel 0 @ 20uA
# 	NEW_FIN_I_M = FIN_I_M * (I_HIGH_SET / I_HIGH_MEAS)
# 	64740 = 64740 * (22.274 µA / 22.274 µA)
# 	V_MAX after Cal = 22.274 µA
# FIN_I_C CALIBRATION for channel 0 @ 20uA
# 	NEW_FIN_C = FIN_C - (Zero_offset / LSB)
# 	33155 = 33155 - (-278.950 pA / 679.779 pA)
# 	Offset after Cal = -233.650 pA
# FIN_I_M CALIBRATION for channel 0 @ 20uA
# 	NEW_FIN_I_M = FIN_I_M * (I_HIGH_SET / I_HIGH_MEAS)
# 	64740 = 64740 * (22.274 µA / 22.274 µA)
# 	V_MAX after Cal = 22.274 µA
# FIN_I_C CALIBRATION for channel 0 @ 20uA
# 	NEW_FIN_C = FIN_C - (Zero_offset / LSB)
# 	33155 = 33155 - (-286.102 pA / 679.779 pA)
# 	Offset after Cal = -247.955 pA
# Calibration OK
# FIN_I_M CALIBRATION for channel 1 @ 20uA
# 	NEW_FIN_I_M = FIN_I_M * (I_HIGH_SET / I_HIGH_MEAS)
# 	64670 = 65535 * (22.274 µA / 22.572 µA)
# 	V_MAX after Cal = 21.976 µA
# FIN_I_C CALIBRATION for channel 1 @ 20uA
# 	NEW_FIN_C = FIN_C - (Zero_offset / LSB)
# 	33189 = 32768 - (-286.081 nA / 679.779 pA)
# 	Offset after Cal = 4.539 nA
# FIN_I_M CALIBRATION for channel 1 @ 20uA
# 	NEW_FIN_I_M = FIN_I_M * (I_HIGH_SET / I_HIGH_MEAS)
# 	64696 = 64670 * (22.274 µA / 22.265 µA)
# 	V_MAX after Cal = 22.283 µA
# FIN_I_C CALIBRATION for channel 1 @ 20uA
# 	NEW_FIN_C = FIN_C - (Zero_offset / LSB)
# 	33169 = 33189 - (13.354 nA / 679.779 pA)
# 	Offset after Cal = -393.391 pA
# FIN_I_M CALIBRATION for channel 1 @ 20uA
# 	NEW_FIN_I_M = FIN_I_M * (I_HIGH_SET / I_HIGH_MEAS)
# 	64709 = 64696 * (22.274 µA / 22.270 µA)
# 	V_MAX after Cal = 22.278 µA
# FIN_I_C CALIBRATION for channel 1 @ 20uA
# 	NEW_FIN_C = FIN_C - (Zero_offset / LSB)
# 	33163 = 33169 - (3.808 nA / 679.779 pA)
# 	Offset after Cal = -779.628 pA
# FIN_I_M CALIBRATION for channel 1 @ 20uA
# 	NEW_FIN_I_M = FIN_I_M * (I_HIGH_SET / I_HIGH_MEAS)
# 	64709 = 64708 * (22.274 µA / 22.274 µA)
# 	V_MAX after Cal = 22.274 µA
# FIN_I_C CALIBRATION for channel 1 @ 20uA
# 	NEW_FIN_C = FIN_C - (Zero_offset / LSB)
# 	33164 = 33163 - (-488.758 pA / 679.779 pA)
# 	Offset after Cal = 166.893 pA
# FIN_I_M CALIBRATION for channel 1 @ 20uA
# 	NEW_FIN_I_M = FIN_I_M * (I_HIGH_SET / I_HIGH_MEAS)
# 	64709 = 64708 * (22.274 µA / 22.274 µA)
# 	V_MAX after Cal = 22.274 µA
# FIN_I_C CALIBRATION for channel 1 @ 20uA
# 	NEW_FIN_C = FIN_C - (Zero_offset / LSB)
# 	33165 = 33164 - (-360.012 pA / 679.779 pA)
# 	Offset after Cal = 696.182 pA
# FIN_I_M CALIBRATION for channel 1 @ 20uA
# 	NEW_FIN_I_M = FIN_I_M * (I_HIGH_SET / I_HIGH_MEAS)
# 	64706 = 64708 * (22.274 µA / 22.275 µA)
# 	V_MAX after Cal = 22.274 µA
# FIN_I_C CALIBRATION for channel 1 @ 20uA
# 	NEW_FIN_C = FIN_C - (Zero_offset / LSB)
# 	33165 = 33165 - (-7.152 pA / 679.779 pA)
# 	Offset after Cal = -83.447 pA
# FIN_I_M CALIBRATION for channel 1 @ 20uA
# 	NEW_FIN_I_M = FIN_I_M * (I_HIGH_SET / I_HIGH_MEAS)
# 	64708 = 64706 * (22.274 µA / 22.274 µA)
# 	V_MAX after Cal = 22.275 µA
# FIN_I_C CALIBRATION for channel 1 @ 20uA
# 	NEW_FIN_C = FIN_C - (Zero_offset / LSB)
# 	33164 = 33165 - (765.324 pA / 679.779 pA)
# 	Offset after Cal = -193.119 pA
# FIN_I_M CALIBRATION for channel 1 @ 20uA
# 	NEW_FIN_I_M = FIN_I_M * (I_HIGH_SET / I_HIGH_MEAS)
# 	64707 = 64708 * (22.274 µA / 22.275 µA)
# 	V_MAX after Cal = 22.273 µA
# FIN_I_C CALIBRATION for channel 1 @ 20uA
# 	NEW_FIN_C = FIN_C - (Zero_offset / LSB)
# 	33166 = 33164 - (-1.078 nA / 679.779 pA)
# 	Offset after Cal = 641.346 pA
# FIN_I_M CALIBRATION for channel 1 @ 20uA
# 	NEW_FIN_I_M = FIN_I_M * (I_HIGH_SET / I_HIGH_MEAS)
# 	64706 = 64706 * (22.274 µA / 22.274 µA)
# 	V_MAX after Cal = 22.275 µA
# FIN_I_C CALIBRATION for channel 1 @ 20uA
# 	NEW_FIN_C = FIN_C - (Zero_offset / LSB)
# 	33164 = 33166 - (1.218 nA / 679.779 pA)
# 	Offset after Cal = -429.154 pA
# FIN_I_M CALIBRATION for channel 1 @ 20uA
# 	NEW_FIN_I_M = FIN_I_M * (I_HIGH_SET / I_HIGH_MEAS)
# 	64709 = 64706 * (22.274 µA / 22.273 µA)
# 	V_MAX after Cal = 22.275 µA
# FIN_I_C CALIBRATION for channel 1 @ 20uA
# 	NEW_FIN_C = FIN_C - (Zero_offset / LSB)
# 	33164 = 33164 - (271.797 pA / 679.779 pA)
# 	Offset after Cal = 383.854 pA
# FIN_I_M CALIBRATION for channel 1 @ 20uA
# 	NEW_FIN_I_M = FIN_I_M * (I_HIGH_SET / I_HIGH_MEAS)
# 	64705 = 64708 * (22.274 µA / 22.275 µA)
# 	V_MAX after Cal = 22.272 µA
# FIN_I_C CALIBRATION for channel 1 @ 20uA
# 	NEW_FIN_C = FIN_C - (Zero_offset / LSB)
# 	33165 = 33164 - (-851.153 pA / 679.779 pA)
# 	Offset after Cal = -467.301 pA
# FIN_I_M CALIBRATION for channel 1 @ 20uA
# 	NEW_FIN_I_M = FIN_I_M * (I_HIGH_SET / I_HIGH_MEAS)
# 	64709 = 64704 * (22.274 µA / 22.273 µA)
# 	V_MAX after Cal = 22.275 µA
# FIN_I_C CALIBRATION for channel 1 @ 20uA
# 	NEW_FIN_C = FIN_C - (Zero_offset / LSB)
# 	33163 = 33165 - (1.149 nA / 679.779 pA)
# 	Offset after Cal = -433.922 pA
# FIN_I_M CALIBRATION for channel 1 @ 20uA
# 	NEW_FIN_I_M = FIN_I_M * (I_HIGH_SET / I_HIGH_MEAS)
# 	64709 = 64708 * (22.274 µA / 22.274 µA)
# 	V_MAX after Cal = 22.274 µA
# FIN_I_C CALIBRATION for channel 1 @ 20uA
# 	NEW_FIN_C = FIN_C - (Zero_offset / LSB)
# 	33163 = 33163 - (-21.458 pA / 679.779 pA)
# 	Offset after Cal = 154.972 pA
# Calibration OK
# FIN_I_M CALIBRATION for channel 2 @ 20uA
# 	NEW_FIN_I_M = FIN_I_M * (I_HIGH_SET / I_HIGH_MEAS)
# 	64789 = 65535 * (22.274 µA / 22.531 µA)
# 	V_MAX after Cal = 22.016 µA
# FIN_I_C CALIBRATION for channel 2 @ 20uA
# 	NEW_FIN_C = FIN_C - (Zero_offset / LSB)
# 	33169 = 32768 - (-272.686 nA / 679.779 pA)
# 	Offset after Cal = 3.693 nA
# FIN_I_M CALIBRATION for channel 2 @ 20uA
# 	NEW_FIN_I_M = FIN_I_M * (I_HIGH_SET / I_HIGH_MEAS)
# 	64735 = 64788 * (22.274 µA / 22.292 µA)
# 	V_MAX after Cal = 22.255 µA
# FIN_I_C CALIBRATION for channel 2 @ 20uA
# 	NEW_FIN_C = FIN_C - (Zero_offset / LSB)
# 	33191 = 33169 - (-14.949 nA / 679.779 pA)
# 	Offset after Cal = 238.419 pA
# FIN_I_M CALIBRATION for channel 2 @ 20uA
# 	NEW_FIN_I_M = FIN_I_M * (I_HIGH_SET / I_HIGH_MEAS)
# 	64747 = 64734 * (22.274 µA / 22.270 µA)
# 	V_MAX after Cal = 22.278 µA
# FIN_I_C CALIBRATION for channel 2 @ 20uA
# 	NEW_FIN_C = FIN_C - (Zero_offset / LSB)
# 	33185 = 33191 - (4.416 nA / 679.779 pA)
# 	Offset after Cal = 495.911 pA
# FIN_I_M CALIBRATION for channel 2 @ 20uA
# 	NEW_FIN_I_M = FIN_I_M * (I_HIGH_SET / I_HIGH_MEAS)
# 	64745 = 64746 * (22.274 µA / 22.275 µA)
# 	V_MAX after Cal = 22.273 µA
# FIN_I_C CALIBRATION for channel 2 @ 20uA
# 	NEW_FIN_C = FIN_C - (Zero_offset / LSB)
# 	33186 = 33185 - (-760.555 pA / 679.779 pA)
# 	Offset after Cal = -402.927 pA
# FIN_I_M CALIBRATION for channel 2 @ 20uA
# 	NEW_FIN_I_M = FIN_I_M * (I_HIGH_SET / I_HIGH_MEAS)
# 	64748 = 64744 * (22.274 µA / 22.273 µA)
# 	V_MAX after Cal = 22.276 µA
# FIN_I_C CALIBRATION for channel 2 @ 20uA
# 	NEW_FIN_C = FIN_C - (Zero_offset / LSB)
# 	33184 = 33186 - (1.228 nA / 679.779 pA)
# 	Offset after Cal = -572.205 pA
# FIN_I_M CALIBRATION for channel 2 @ 20uA
# 	NEW_FIN_I_M = FIN_I_M * (I_HIGH_SET / I_HIGH_MEAS)
# 	64748 = 64748 * (22.274 µA / 22.274 µA)
# 	V_MAX after Cal = 22.274 µA
# FIN_I_C CALIBRATION for channel 2 @ 20uA
# 	NEW_FIN_C = FIN_C - (Zero_offset / LSB)
# 	33184 = 33184 - (238.419 pA / 679.779 pA)
# 	Offset after Cal = 474.453 pA
# Calibration OK
# FIN_I_M CALIBRATION for channel 3 @ 20uA
# 	NEW_FIN_I_M = FIN_I_M * (I_HIGH_SET / I_HIGH_MEAS)
# 	64696 = 65535 * (22.274 µA / 22.563 µA)
# 	V_MAX after Cal = 21.984 µA
# FIN_I_C CALIBRATION for channel 3 @ 20uA
# 	NEW_FIN_C = FIN_C - (Zero_offset / LSB)
# 	33188 = 32768 - (-285.516 nA / 679.779 pA)
# 	Offset after Cal = 4.120 nA
# FIN_I_M CALIBRATION for channel 3 @ 20uA
# 	NEW_FIN_I_M = FIN_I_M * (I_HIGH_SET / I_HIGH_MEAS)
# 	64698 = 64696 * (22.274 µA / 22.274 µA)
# 	V_MAX after Cal = 22.275 µA
# FIN_I_C CALIBRATION for channel 3 @ 20uA
# 	NEW_FIN_C = FIN_C - (Zero_offset / LSB)
# 	33181 = 33188 - (4.506 nA / 679.779 pA)
# 	Offset after Cal = -250.339 pA
# FIN_I_M CALIBRATION for channel 3 @ 20uA
# 	NEW_FIN_I_M = FIN_I_M * (I_HIGH_SET / I_HIGH_MEAS)
# 	64710 = 64698 * (22.274 µA / 22.270 µA)
# 	V_MAX after Cal = 22.278 µA
# FIN_I_C CALIBRATION for channel 3 @ 20uA
# 	NEW_FIN_C = FIN_C - (Zero_offset / LSB)
# 	33176 = 33181 - (3.686 nA / 679.779 pA)
# 	Offset after Cal = 572.205 pA
# FIN_I_M CALIBRATION for channel 3 @ 20uA
# 	NEW_FIN_I_M = FIN_I_M * (I_HIGH_SET / I_HIGH_MEAS)
# 	64708 = 64710 * (22.274 µA / 22.275 µA)
# 	V_MAX after Cal = 22.273 µA
# FIN_I_C CALIBRATION for channel 3 @ 20uA
# 	NEW_FIN_C = FIN_C - (Zero_offset / LSB)
# 	33176 = 33176 - (-169.277 pA / 679.779 pA)
# 	Offset after Cal = -66.757 pA
# FIN_I_M CALIBRATION for channel 3 @ 20uA
# 	NEW_FIN_I_M = FIN_I_M * (I_HIGH_SET / I_HIGH_MEAS)
# 	64710 = 64708 * (22.274 µA / 22.274 µA)
# 	V_MAX after Cal = 22.275 µA
# FIN_I_C CALIBRATION for channel 3 @ 20uA
# 	NEW_FIN_C = FIN_C - (Zero_offset / LSB)
# 	33175 = 33176 - (472.069 pA / 679.779 pA)
# 	Offset after Cal = -700.950 pA
# FIN_I_M CALIBRATION for channel 3 @ 20uA
# 	NEW_FIN_I_M = FIN_I_M * (I_HIGH_SET / I_HIGH_MEAS)
# 	64711 = 64710 * (22.274 µA / 22.274 µA)
# 	V_MAX after Cal = 22.274 µA
# FIN_I_C CALIBRATION for channel 3 @ 20uA
# 	NEW_FIN_C = FIN_C - (Zero_offset / LSB)
# 	33176 = 33175 - (-340.938 pA / 679.779 pA)
# 	Offset after Cal = 529.289 pA
# FIN_I_M CALIBRATION for channel 3 @ 20uA
# 	NEW_FIN_I_M = FIN_I_M * (I_HIGH_SET / I_HIGH_MEAS)
# 	64709 = 64710 * (22.274 µA / 22.275 µA)
# 	V_MAX after Cal = 22.273 µA
# FIN_I_C CALIBRATION for channel 3 @ 20uA
# 	NEW_FIN_C = FIN_C - (Zero_offset / LSB)
# 	33176 = 33176 - (-288.486 pA / 679.779 pA)
# 	Offset after Cal = -469.684 pA
# FIN_I_M CALIBRATION for channel 3 @ 20uA
# 	NEW_FIN_I_M = FIN_I_M * (I_HIGH_SET / I_HIGH_MEAS)
# 	64711 = 64708 * (22.274 µA / 22.273 µA)
# 	V_MAX after Cal = 22.274 µA
# FIN_I_C CALIBRATION for channel 3 @ 20uA
# 	NEW_FIN_C = FIN_C - (Zero_offset / LSB)
# 	33175 = 33176 - (679.494 pA / 679.779 pA)
# 	Offset after Cal = -90.599 pA
# FIN_I_M CALIBRATION for channel 3 @ 20uA
# 	NEW_FIN_I_M = FIN_I_M * (I_HIGH_SET / I_HIGH_MEAS)
# 	64711 = 64710 * (22.274 µA / 22.274 µA)
# 	V_MAX after Cal = 22.273 µA
# FIN_I_C CALIBRATION for channel 3 @ 20uA
# 	NEW_FIN_C = FIN_C - (Zero_offset / LSB)
# 	33176 = 33175 - (-624.657 pA / 679.779 pA)
# 	Offset after Cal = 586.510 pA
# FIN_I_M CALIBRATION for channel 3 @ 20uA
# 	NEW_FIN_I_M = FIN_I_M * (I_HIGH_SET / I_HIGH_MEAS)
# 	64710 = 64710 * (22.274 µA / 22.274 µA)
# 	V_MAX after Cal = 22.274 µA
# FIN_I_C CALIBRATION for channel 3 @ 20uA
# 	NEW_FIN_C = FIN_C - (Zero_offset / LSB)
# 	33175 = 33176 - (479.221 pA / 679.779 pA)
# 	Offset after Cal = -514.984 pA
# FIN_I_M CALIBRATION for channel 3 @ 20uA
# 	NEW_FIN_I_M = FIN_I_M * (I_HIGH_SET / I_HIGH_MEAS)
# 	64712 = 64710 * (22.274 µA / 22.274 µA)
# 	V_MAX after Cal = 22.275 µA
# FIN_I_C CALIBRATION for channel 3 @ 20uA
# 	NEW_FIN_C = FIN_C - (Zero_offset / LSB)
# 	33174 = 33175 - (612.736 pA / 679.779 pA)
# 	Offset after Cal = -169.277 pA
# FIN_I_M CALIBRATION for channel 3 @ 20uA
# 	NEW_FIN_I_M = FIN_I_M * (I_HIGH_SET / I_HIGH_MEAS)
# 	64710 = 64712 * (22.274 µA / 22.275 µA)
# 	V_MAX after Cal = 22.273 µA
# FIN_I_C CALIBRATION for channel 3 @ 20uA
# 	NEW_FIN_C = FIN_C - (Zero_offset / LSB)
# 	33176 = 33174 - (-1.101 nA / 679.779 pA)
# 	Offset after Cal = 121.593 pA
# FIN_I_M CALIBRATION for channel 3 @ 20uA
# 	NEW_FIN_I_M = FIN_I_M * (I_HIGH_SET / I_HIGH_MEAS)
# 	64710 = 64710 * (22.274 µA / 22.274 µA)
# 	V_MAX after Cal = 22.274 µA
# FIN_I_C CALIBRATION for channel 3 @ 20uA
# 	NEW_FIN_C = FIN_C - (Zero_offset / LSB)
# 	33176 = 33176 - (-119.209 pA / 679.779 pA)
# 	Offset after Cal = 276.566 pA
# Calibration OK
# FIN_I_M CALIBRATION for channel 0 @ 200uA
# 	NEW_FIN_I_M = FIN_I_M * (I_HIGH_SET / I_HIGH_MEAS)
# 	64735 = 65535 * (222.743 µA / 225.496 µA)
# 	V_MAX after Cal = 219.974 µA
# FIN_I_C CALIBRATION for channel 0 @ 200uA
# 	NEW_FIN_C = FIN_C - (Zero_offset / LSB)
# 	33183 = 32768 - (-2.821 µA / 6.798 nA)
# 	Offset after Cal = 36.812 nA
# FIN_I_M CALIBRATION for channel 0 @ 200uA
# 	NEW_FIN_I_M = FIN_I_M * (I_HIGH_SET / I_HIGH_MEAS)
# 	64707 = 64734 * (222.743 µA / 222.835 µA)
# 	V_MAX after Cal = 222.640 µA
# FIN_I_C CALIBRATION for channel 0 @ 200uA
# 	NEW_FIN_C = FIN_C - (Zero_offset / LSB)
# 	33192 = 33183 - (-60.248 nA / 6.798 nA)
# 	Offset after Cal = 1.574 nA
# FIN_I_M CALIBRATION for channel 0 @ 200uA
# 	NEW_FIN_I_M = FIN_I_M * (I_HIGH_SET / I_HIGH_MEAS)
# 	64718 = 64706 * (222.743 µA / 222.700 µA)
# 	V_MAX after Cal = 222.783 µA
# FIN_I_C CALIBRATION for channel 0 @ 200uA
# 	NEW_FIN_C = FIN_C - (Zero_offset / LSB)
# 	33186 = 33192 - (41.771 nA / 6.798 nA)
# 	Offset after Cal = -1.240 nA
# FIN_I_M CALIBRATION for channel 0 @ 200uA
# 	NEW_FIN_I_M = FIN_I_M * (I_HIGH_SET / I_HIGH_MEAS)
# 	64718 = 64718 * (222.743 µA / 222.742 µA)
# 	V_MAX after Cal = 222.742 µA
# FIN_I_C CALIBRATION for channel 0 @ 200uA
# 	NEW_FIN_C = FIN_C - (Zero_offset / LSB)
# 	33186 = 33186 - (1.431 nA / 6.798 nA)
# 	Offset after Cal = 429.153 pA
# Calibration OK
# FIN_I_M CALIBRATION for channel 1 @ 200uA
# 	NEW_FIN_I_M = FIN_I_M * (I_HIGH_SET / I_HIGH_MEAS)
# 	64705 = 65535 * (222.743 µA / 225.599 µA)
# 	V_MAX after Cal = 219.870 µA
# FIN_I_C CALIBRATION for channel 1 @ 200uA
# 	NEW_FIN_C = FIN_C - (Zero_offset / LSB)
# 	33191 = 32768 - (-2.873 µA / 6.798 nA)
# 	Offset after Cal = 40.722 nA
# FIN_I_M CALIBRATION for channel 1 @ 200uA
# 	NEW_FIN_I_M = FIN_I_M * (I_HIGH_SET / I_HIGH_MEAS)
# 	64693 = 64704 * (222.743 µA / 222.780 µA)
# 	V_MAX after Cal = 222.697 µA
# FIN_I_C CALIBRATION for channel 1 @ 200uA
# 	NEW_FIN_C = FIN_C - (Zero_offset / LSB)
# 	33192 = 33191 - (-4.983 nA / 6.798 nA)
# 	Offset after Cal = 3.195 nA
# FIN_I_M CALIBRATION for channel 1 @ 200uA
# 	NEW_FIN_I_M = FIN_I_M * (I_HIGH_SET / I_HIGH_MEAS)
# 	64703 = 64692 * (222.743 µA / 222.704 µA)
# 	V_MAX after Cal = 222.773 µA
# FIN_I_C CALIBRATION for channel 1 @ 200uA
# 	NEW_FIN_C = FIN_C - (Zero_offset / LSB)
# 	33186 = 33192 - (38.624 nA / 6.798 nA)
# 	Offset after Cal = -3.505 nA
# FIN_I_M CALIBRATION for channel 1 @ 200uA
# 	NEW_FIN_I_M = FIN_I_M * (I_HIGH_SET / I_HIGH_MEAS)
# 	64705 = 64702 * (222.743 µA / 222.732 µA)
# 	V_MAX after Cal = 222.745 µA
# FIN_I_C CALIBRATION for channel 1 @ 200uA
# 	NEW_FIN_C = FIN_C - (Zero_offset / LSB)
# 	33185 = 33186 - (3.910 nA / 6.798 nA)
# 	Offset after Cal = -2.933 nA
# FIN_I_M CALIBRATION for channel 1 @ 200uA
# 	NEW_FIN_I_M = FIN_I_M * (I_HIGH_SET / I_HIGH_MEAS)
# 	64705 = 64704 * (222.743 µA / 222.739 µA)
# 	V_MAX after Cal = 222.740 µA
# FIN_I_C CALIBRATION for channel 1 @ 200uA
# 	NEW_FIN_C = FIN_C - (Zero_offset / LSB)
# 	33185 = 33185 - (-3.386 nA / 6.798 nA)
# 	Offset after Cal = -3.886 nA
# Calibration OK
# FIN_I_M CALIBRATION for channel 2 @ 200uA
# 	NEW_FIN_I_M = FIN_I_M * (I_HIGH_SET / I_HIGH_MEAS)
# 	64821 = 65535 * (222.743 µA / 225.197 µA)
# 	V_MAX after Cal = 220.270 µA
# FIN_I_C CALIBRATION for channel 2 @ 200uA
# 	NEW_FIN_C = FIN_C - (Zero_offset / LSB)
# 	33173 = 32768 - (-2.753 µA / 6.798 nA)
# 	Offset after Cal = 35.834 nA
# FIN_I_M CALIBRATION for channel 2 @ 200uA
# 	NEW_FIN_I_M = FIN_I_M * (I_HIGH_SET / I_HIGH_MEAS)
# 	64729 = 64820 * (222.743 µA / 223.058 µA)
# 	V_MAX after Cal = 222.425 µA
# FIN_I_C CALIBRATION for channel 2 @ 200uA
# 	NEW_FIN_C = FIN_C - (Zero_offset / LSB)
# 	33214 = 33173 - (-280.714 nA / 6.798 nA)
# 	Offset after Cal = 905.990 pA
# FIN_I_M CALIBRATION for channel 2 @ 200uA
# 	NEW_FIN_I_M = FIN_I_M * (I_HIGH_SET / I_HIGH_MEAS)
# 	64739 = 64728 * (222.743 µA / 222.707 µA)
# 	V_MAX after Cal = 222.776 µA
# FIN_I_C CALIBRATION for channel 2 @ 200uA
# 	NEW_FIN_C = FIN_C - (Zero_offset / LSB)
# 	33209 = 33214 - (37.313 nA / 6.798 nA)
# 	Offset after Cal = 572.204 pA
# FIN_I_M CALIBRATION for channel 2 @ 200uA
# 	NEW_FIN_I_M = FIN_I_M * (I_HIGH_SET / I_HIGH_MEAS)
# 	64738 = 64738 * (222.743 µA / 222.742 µA)
# 	V_MAX after Cal = 222.742 µA
# FIN_I_C CALIBRATION for channel 2 @ 200uA
# 	NEW_FIN_C = FIN_C - (Zero_offset / LSB)
# 	33209 = 33209 - (1.812 nA / 6.798 nA)
# 	Offset after Cal = 1.264 nA
# FIN_I_M CALIBRATION for channel 2 @ 200uA
# 	NEW_FIN_I_M = FIN_I_M * (I_HIGH_SET / I_HIGH_MEAS)
# 	64738 = 64738 * (222.743 µA / 222.742 µA)
# 	V_MAX after Cal = 222.742 µA
# FIN_I_C CALIBRATION for channel 2 @ 200uA
# 	NEW_FIN_C = FIN_C - (Zero_offset / LSB)
# 	33209 = 33209 - (2.027 nA / 6.798 nA)
# 	Offset after Cal = 1.645 nA
# Calibration OK
# FIN_I_M CALIBRATION for channel 3 @ 200uA
# 	NEW_FIN_I_M = FIN_I_M * (I_HIGH_SET / I_HIGH_MEAS)
# 	64724 = 65535 * (222.743 µA / 225.533 µA)
# 	V_MAX after Cal = 219.940 µA
# FIN_I_C CALIBRATION for channel 3 @ 200uA
# 	NEW_FIN_C = FIN_C - (Zero_offset / LSB)
# 	33194 = 32768 - (-2.898 µA / 6.798 nA)
# 	Offset after Cal = 37.932 nA
# FIN_I_M CALIBRATION for channel 3 @ 200uA
# 	NEW_FIN_I_M = FIN_I_M * (I_HIGH_SET / I_HIGH_MEAS)
# 	64686 = 64724 * (222.743 µA / 222.874 µA)
# 	V_MAX after Cal = 222.611 µA
# FIN_I_C CALIBRATION for channel 3 @ 200uA
# 	NEW_FIN_C = FIN_C - (Zero_offset / LSB)
# 	33208 = 33194 - (-94.199 nA / 6.798 nA)
# 	Offset after Cal = 2.265 nA
# FIN_I_M CALIBRATION for channel 3 @ 200uA
# 	NEW_FIN_I_M = FIN_I_M * (I_HIGH_SET / I_HIGH_MEAS)
# 	64696 = 64686 * (222.743 µA / 222.707 µA)
# 	V_MAX after Cal = 222.777 µA
# FIN_I_C CALIBRATION for channel 3 @ 200uA
# 	NEW_FIN_C = FIN_C - (Zero_offset / LSB)
# 	33202 = 33208 - (38.099 nA / 6.798 nA)
# 	Offset after Cal = -5.460 nA
# FIN_I_M CALIBRATION for channel 3 @ 200uA
# 	NEW_FIN_I_M = FIN_I_M * (I_HIGH_SET / I_HIGH_MEAS)
# 	64699 = 64696 * (222.743 µA / 222.734 µA)
# 	V_MAX after Cal = 222.749 µA
# FIN_I_C CALIBRATION for channel 3 @ 200uA
# 	NEW_FIN_C = FIN_C - (Zero_offset / LSB)
# 	33202 = 33202 - (762.939 pA / 6.798 nA)
# 	Offset after Cal = 739.097 pA
# FIN_I_M CALIBRATION for channel 3 @ 200uA
# 	NEW_FIN_I_M = FIN_I_M * (I_HIGH_SET / I_HIGH_MEAS)
# 	64696 = 64698 * (222.743 µA / 222.748 µA)
# 	V_MAX after Cal = 222.735 µA
# FIN_I_C CALIBRATION for channel 3 @ 200uA
# 	NEW_FIN_C = FIN_C - (Zero_offset / LSB)
# 	33203 = 33202 - (-4.125 nA / 6.798 nA)
# 	Offset after Cal = 3.171 nA
# FIN_I_M CALIBRATION for channel 3 @ 200uA
# 	NEW_FIN_I_M = FIN_I_M * (I_HIGH_SET / I_HIGH_MEAS)
# 	64696 = 64696 * (222.743 µA / 222.744 µA)
# 	V_MAX after Cal = 222.745 µA
# FIN_I_C CALIBRATION for channel 3 @ 200uA
# 	NEW_FIN_C = FIN_C - (Zero_offset / LSB)
# 	33203 = 33203 - (2.742 nA / 6.798 nA)
# 	Offset after Cal = 2.623 nA
# Calibration OK
# FIN_I_M CALIBRATION for channel 0 @ 2mA
# 	NEW_FIN_I_M = FIN_I_M * (I_HIGH_SET / I_HIGH_MEAS)
# 	64719 = 65535 * (2.227 mA / 2.255 mA)
# 	V_MAX after Cal = 2.199 mA
# FIN_I_C CALIBRATION for channel 0 @ 2mA
# 	NEW_FIN_C = FIN_C - (Zero_offset / LSB)
# 	33177 = 32768 - (-27.786 µA / 67.978 nA)
# 	Offset after Cal = 433.207 nA
# FIN_I_M CALIBRATION for channel 0 @ 2mA
# 	NEW_FIN_I_M = FIN_I_M * (I_HIGH_SET / I_HIGH_MEAS)
# 	64719 = 64718 * (2.227 mA / 2.227 mA)
# 	V_MAX after Cal = 2.227 mA
# FIN_I_C CALIBRATION for channel 0 @ 2mA
# 	NEW_FIN_C = FIN_C - (Zero_offset / LSB)
# 	33170 = 33177 - (476.599 nA / 67.978 nA)
# 	Offset after Cal = 13.590 nA
# FIN_I_M CALIBRATION for channel 0 @ 2mA
# 	NEW_FIN_I_M = FIN_I_M * (I_HIGH_SET / I_HIGH_MEAS)
# 	64731 = 64718 * (2.227 mA / 2.227 mA)
# 	V_MAX after Cal = 2.228 mA
# FIN_I_C CALIBRATION for channel 0 @ 2mA
# 	NEW_FIN_C = FIN_C - (Zero_offset / LSB)
# 	33163 = 33170 - (477.791 nA / 67.978 nA)
# 	Offset after Cal = -10.014 nA
# FIN_I_M CALIBRATION for channel 0 @ 2mA
# 	NEW_FIN_I_M = FIN_I_M * (I_HIGH_SET / I_HIGH_MEAS)
# 	64731 = 64730 * (2.227 mA / 2.227 mA)
# 	V_MAX after Cal = 2.227 mA
# FIN_I_C CALIBRATION for channel 0 @ 2mA
# 	NEW_FIN_C = FIN_C - (Zero_offset / LSB)
# 	33164 = 33163 - (-46.730 nA / 67.978 nA)
# 	Offset after Cal = -27.657 nA
# FIN_I_M CALIBRATION for channel 0 @ 2mA
# 	NEW_FIN_I_M = FIN_I_M * (I_HIGH_SET / I_HIGH_MEAS)
# 	64731 = 64730 * (2.227 mA / 2.227 mA)
# 	V_MAX after Cal = 2.227 mA
# FIN_I_C CALIBRATION for channel 0 @ 2mA
# 	NEW_FIN_C = FIN_C - (Zero_offset / LSB)
# 	33164 = 33164 - (-18.597 nA / 67.978 nA)
# 	Offset after Cal = -26.703 nA
# Calibration OK
# FIN_I_M CALIBRATION for channel 1 @ 2mA
# 	NEW_FIN_I_M = FIN_I_M * (I_HIGH_SET / I_HIGH_MEAS)
# 	64673 = 65535 * (2.227 mA / 2.257 mA)
# 	V_MAX after Cal = 2.198 mA
# FIN_I_C CALIBRATION for channel 1 @ 2mA
# 	NEW_FIN_C = FIN_C - (Zero_offset / LSB)
# 	33191 = 32768 - (-28.765 µA / 67.978 nA)
# 	Offset after Cal = 362.635 nA
# FIN_I_M CALIBRATION for channel 1 @ 2mA
# 	NEW_FIN_I_M = FIN_I_M * (I_HIGH_SET / I_HIGH_MEAS)
# 	64690 = 64672 * (2.227 mA / 2.227 mA)
# 	V_MAX after Cal = 2.228 mA
# FIN_I_C CALIBRATION for channel 1 @ 2mA
# 	NEW_FIN_C = FIN_C - (Zero_offset / LSB)
# 	33175 = 33191 - (1.059 µA / 67.978 nA)
# 	Offset after Cal = -44.823 nA
# FIN_I_M CALIBRATION for channel 1 @ 2mA
# 	NEW_FIN_I_M = FIN_I_M * (I_HIGH_SET / I_HIGH_MEAS)
# 	64704 = 64690 * (2.227 mA / 2.227 mA)
# 	V_MAX after Cal = 2.228 mA
# FIN_I_C CALIBRATION for channel 1 @ 2mA
# 	NEW_FIN_C = FIN_C - (Zero_offset / LSB)
# 	33168 = 33175 - (464.439 nA / 67.978 nA)
# 	Offset after Cal = -8.106 nA
# FIN_I_M CALIBRATION for channel 1 @ 2mA
# 	NEW_FIN_I_M = FIN_I_M * (I_HIGH_SET / I_HIGH_MEAS)
# 	64703 = 64704 * (2.227 mA / 2.227 mA)
# 	V_MAX after Cal = 2.227 mA
# FIN_I_C CALIBRATION for channel 1 @ 2mA
# 	NEW_FIN_C = FIN_C - (Zero_offset / LSB)
# 	33169 = 33168 - (-82.970 nA / 67.978 nA)
# 	Offset after Cal = -21.219 nA
# FIN_I_M CALIBRATION for channel 1 @ 2mA
# 	NEW_FIN_I_M = FIN_I_M * (I_HIGH_SET / I_HIGH_MEAS)
# 	64703 = 64702 * (2.227 mA / 2.227 mA)
# 	V_MAX after Cal = 2.227 mA
# FIN_I_C CALIBRATION for channel 1 @ 2mA
# 	NEW_FIN_C = FIN_C - (Zero_offset / LSB)
# 	33169 = 33169 - (17.166 nA / 67.978 nA)
# 	Offset after Cal = -22.411 nA
# Calibration OK
# FIN_I_M CALIBRATION for channel 2 @ 2mA
# 	NEW_FIN_I_M = FIN_I_M * (I_HIGH_SET / I_HIGH_MEAS)
# 	64808 = 65535 * (2.227 mA / 2.252 mA)
# 	V_MAX after Cal = 2.202 mA
# FIN_I_C CALIBRATION for channel 2 @ 2mA
# 	NEW_FIN_C = FIN_C - (Zero_offset / LSB)
# 	33162 = 32768 - (-26.775 µA / 67.978 nA)
# 	Offset after Cal = 342.131 nA
# FIN_I_M CALIBRATION for channel 2 @ 2mA
# 	NEW_FIN_I_M = FIN_I_M * (I_HIGH_SET / I_HIGH_MEAS)
# 	64748 = 64808 * (2.227 mA / 2.230 mA)
# 	V_MAX after Cal = 2.225 mA
# FIN_I_C CALIBRATION for channel 2 @ 2mA
# 	NEW_FIN_C = FIN_C - (Zero_offset / LSB)
# 	33188 = 33162 - (-1.739 µA / 67.978 nA)
# 	Offset after Cal = 62.227 nA
# FIN_I_M CALIBRATION for channel 2 @ 2mA
# 	NEW_FIN_I_M = FIN_I_M * (I_HIGH_SET / I_HIGH_MEAS)
# 	64756 = 64748 * (2.227 mA / 2.227 mA)
# 	V_MAX after Cal = 2.228 mA
# FIN_I_C CALIBRATION for channel 2 @ 2mA
# 	NEW_FIN_C = FIN_C - (Zero_offset / LSB)
# 	33183 = 33188 - (316.858 nA / 67.978 nA)
# 	Offset after Cal = -40.293 nA
# FIN_I_M CALIBRATION for channel 2 @ 2mA
# 	NEW_FIN_I_M = FIN_I_M * (I_HIGH_SET / I_HIGH_MEAS)
# 	64759 = 64756 * (2.227 mA / 2.227 mA)
# 	V_MAX after Cal = 2.227 mA
# FIN_I_C CALIBRATION for channel 2 @ 2mA
# 	NEW_FIN_C = FIN_C - (Zero_offset / LSB)
# 	33182 = 33183 - (63.181 nA / 67.978 nA)
# 	Offset after Cal = -21.696 nA
# FIN_I_M CALIBRATION for channel 2 @ 2mA
# 	NEW_FIN_I_M = FIN_I_M * (I_HIGH_SET / I_HIGH_MEAS)
# 	64758 = 64758 * (2.227 mA / 2.227 mA)
# 	V_MAX after Cal = 2.227 mA
# FIN_I_C CALIBRATION for channel 2 @ 2mA
# 	NEW_FIN_C = FIN_C - (Zero_offset / LSB)
# 	33182 = 33182 - (-8.583 nA / 67.978 nA)
# 	Offset after Cal = -12.159 nA
# FIN_I_M CALIBRATION for channel 2 @ 2mA
# 	NEW_FIN_I_M = FIN_I_M * (I_HIGH_SET / I_HIGH_MEAS)
# 	64758 = 64758 * (2.227 mA / 2.227 mA)
# 	V_MAX after Cal = 2.227 mA
# FIN_I_C CALIBRATION for channel 2 @ 2mA
# 	NEW_FIN_C = FIN_C - (Zero_offset / LSB)
# 	33183 = 33182 - (-46.253 nA / 67.978 nA)
# 	Offset after Cal = 24.319 nA
# FIN_I_M CALIBRATION for channel 2 @ 2mA
# 	NEW_FIN_I_M = FIN_I_M * (I_HIGH_SET / I_HIGH_MEAS)
# 	64755 = 64758 * (2.227 mA / 2.228 mA)
# 	V_MAX after Cal = 2.227 mA
# FIN_I_C CALIBRATION for channel 2 @ 2mA
# 	NEW_FIN_C = FIN_C - (Zero_offset / LSB)
# 	33184 = 33183 - (-83.208 nA / 67.978 nA)
# 	Offset after Cal = -46.015 nA
# FIN_I_M CALIBRATION for channel 2 @ 2mA
# 	NEW_FIN_I_M = FIN_I_M * (I_HIGH_SET / I_HIGH_MEAS)
# 	64758 = 64754 * (2.227 mA / 2.227 mA)
# 	V_MAX after Cal = 2.228 mA
# FIN_I_C CALIBRATION for channel 2 @ 2mA
# 	NEW_FIN_C = FIN_C - (Zero_offset / LSB)
# 	33182 = 33184 - (104.189 nA / 67.978 nA)
# 	Offset after Cal = 5.960 nA
# FIN_I_M CALIBRATION for channel 2 @ 2mA
# 	NEW_FIN_I_M = FIN_I_M * (I_HIGH_SET / I_HIGH_MEAS)
# 	64760 = 64758 * (2.227 mA / 2.227 mA)
# 	V_MAX after Cal = 2.227 mA
# FIN_I_C CALIBRATION for channel 2 @ 2mA
# 	NEW_FIN_C = FIN_C - (Zero_offset / LSB)
# 	33183 = 33182 - (-58.174 nA / 67.978 nA)
# 	Offset after Cal = 51.260 nA
# FIN_I_M CALIBRATION for channel 2 @ 2mA
# 	NEW_FIN_I_M = FIN_I_M * (I_HIGH_SET / I_HIGH_MEAS)
# 	64755 = 64760 * (2.227 mA / 2.228 mA)
# 	V_MAX after Cal = 2.227 mA
# FIN_I_C CALIBRATION for channel 2 @ 2mA
# 	NEW_FIN_C = FIN_C - (Zero_offset / LSB)
# 	33184 = 33183 - (-99.421 nA / 67.978 nA)
# 	Offset after Cal = -25.272 nA
# FIN_I_M CALIBRATION for channel 2 @ 2mA
# 	NEW_FIN_I_M = FIN_I_M * (I_HIGH_SET / I_HIGH_MEAS)
# 	64759 = 64754 * (2.227 mA / 2.227 mA)
# 	V_MAX after Cal = 2.228 mA
# FIN_I_C CALIBRATION for channel 2 @ 2mA
# 	NEW_FIN_C = FIN_C - (Zero_offset / LSB)
# 	33182 = 33184 - (142.336 nA / 67.978 nA)
# 	Offset after Cal = -34.332 nA
# FIN_I_M CALIBRATION for channel 2 @ 2mA
# 	NEW_FIN_I_M = FIN_I_M * (I_HIGH_SET / I_HIGH_MEAS)
# 	64759 = 64758 * (2.227 mA / 2.227 mA)
# 	V_MAX after Cal = 2.227 mA
# FIN_I_C CALIBRATION for channel 2 @ 2mA
# 	NEW_FIN_C = FIN_C - (Zero_offset / LSB)
# 	33182 = 33182 - (-30.994 nA / 67.978 nA)
# 	Offset after Cal = -42.677 nA
# Calibration OK
# FIN_I_M CALIBRATION for channel 3 @ 2mA
# 	NEW_FIN_I_M = FIN_I_M * (I_HIGH_SET / I_HIGH_MEAS)
# 	64706 = 65535 * (2.227 mA / 2.256 mA)
# 	V_MAX after Cal = 2.199 mA
# FIN_I_C CALIBRATION for channel 3 @ 2mA
# 	NEW_FIN_C = FIN_C - (Zero_offset / LSB)
# 	33187 = 32768 - (-28.482 µA / 67.978 nA)
# 	Offset after Cal = 384.808 nA
# FIN_I_M CALIBRATION for channel 3 @ 2mA
# 	NEW_FIN_I_M = FIN_I_M * (I_HIGH_SET / I_HIGH_MEAS)
# 	64700 = 64706 * (2.227 mA / 2.228 mA)
# 	V_MAX after Cal = 2.227 mA
# FIN_I_C CALIBRATION for channel 3 @ 2mA
# 	NEW_FIN_C = FIN_C - (Zero_offset / LSB)
# 	33185 = 33187 - (142.336 nA / 67.978 nA)
# 	Offset after Cal = 36.001 nA
# FIN_I_M CALIBRATION for channel 3 @ 2mA
# 	NEW_FIN_I_M = FIN_I_M * (I_HIGH_SET / I_HIGH_MEAS)
# 	64712 = 64700 * (2.227 mA / 2.227 mA)
# 	V_MAX after Cal = 2.228 mA
# FIN_I_C CALIBRATION for channel 3 @ 2mA
# 	NEW_FIN_C = FIN_C - (Zero_offset / LSB)
# 	33179 = 33185 - (423.670 nA / 67.978 nA)
# 	Offset after Cal = -11.444 nA
# FIN_I_M CALIBRATION for channel 3 @ 2mA
# 	NEW_FIN_I_M = FIN_I_M * (I_HIGH_SET / I_HIGH_MEAS)
# 	64710 = 64712 * (2.227 mA / 2.227 mA)
# 	V_MAX after Cal = 2.227 mA
# FIN_I_C CALIBRATION for channel 3 @ 2mA
# 	NEW_FIN_C = FIN_C - (Zero_offset / LSB)
# 	33180 = 33179 - (-38.385 nA / 67.978 nA)
# 	Offset after Cal = 30.041 nA
# FIN_I_M CALIBRATION for channel 3 @ 2mA
# 	NEW_FIN_I_M = FIN_I_M * (I_HIGH_SET / I_HIGH_MEAS)
# 	64710 = 64710 * (2.227 mA / 2.227 mA)
# 	V_MAX after Cal = 2.227 mA
# FIN_I_C CALIBRATION for channel 3 @ 2mA
# 	NEW_FIN_C = FIN_C - (Zero_offset / LSB)
# 	33179 = 33180 - (39.101 nA / 67.978 nA)
# 	Offset after Cal = -16.928 nA
# FIN_I_M CALIBRATION for channel 3 @ 2mA
# 	NEW_FIN_I_M = FIN_I_M * (I_HIGH_SET / I_HIGH_MEAS)
# 	64713 = 64710 * (2.227 mA / 2.227 mA)
# 	V_MAX after Cal = 2.227 mA
# FIN_I_C CALIBRATION for channel 3 @ 2mA
# 	NEW_FIN_C = FIN_C - (Zero_offset / LSB)
# 	33178 = 33179 - (51.022 nA / 67.978 nA)
# 	Offset after Cal = -27.895 nA
# FIN_I_M CALIBRATION for channel 3 @ 2mA
# 	NEW_FIN_I_M = FIN_I_M * (I_HIGH_SET / I_HIGH_MEAS)
# 	64714 = 64712 * (2.227 mA / 2.227 mA)
# 	V_MAX after Cal = 2.227 mA
# FIN_I_C CALIBRATION for channel 3 @ 2mA
# 	NEW_FIN_C = FIN_C - (Zero_offset / LSB)
# 	33178 = 33178 - (28.610 nA / 67.978 nA)
# 	Offset after Cal = -12.636 nA
# FIN_I_M CALIBRATION for channel 3 @ 2mA
# 	NEW_FIN_I_M = FIN_I_M * (I_HIGH_SET / I_HIGH_MEAS)
# 	64710 = 64714 * (2.227 mA / 2.228 mA)
# 	V_MAX after Cal = 2.227 mA
# FIN_I_C CALIBRATION for channel 3 @ 2mA
# 	NEW_FIN_C = FIN_C - (Zero_offset / LSB)
# 	33180 = 33178 - (-155.449 nA / 67.978 nA)
# 	Offset after Cal = -16.212 nA
# FIN_I_M CALIBRATION for channel 3 @ 2mA
# 	NEW_FIN_I_M = FIN_I_M * (I_HIGH_SET / I_HIGH_MEAS)
# 	64711 = 64710 * (2.227 mA / 2.227 mA)
# 	V_MAX after Cal = 2.227 mA
# FIN_I_C CALIBRATION for channel 3 @ 2mA
# 	NEW_FIN_C = FIN_C - (Zero_offset / LSB)
# 	33179 = 33180 - (50.068 nA / 67.978 nA)
# 	Offset after Cal = -28.372 nA
# FIN_I_M CALIBRATION for channel 3 @ 2mA
# 	NEW_FIN_I_M = FIN_I_M * (I_HIGH_SET / I_HIGH_MEAS)
# 	64712 = 64710 * (2.227 mA / 2.227 mA)
# 	V_MAX after Cal = 2.227 mA
# FIN_I_C CALIBRATION for channel 3 @ 2mA
# 	NEW_FIN_C = FIN_C - (Zero_offset / LSB)
# 	33179 = 33179 - (10.490 nA / 67.978 nA)
# 	Offset after Cal = 21.458 nA
# FIN_I_M CALIBRATION for channel 3 @ 2mA
# 	NEW_FIN_I_M = FIN_I_M * (I_HIGH_SET / I_HIGH_MEAS)
# 	64710 = 64712 * (2.227 mA / 2.227 mA)
# 	V_MAX after Cal = 2.227 mA
# FIN_I_C CALIBRATION for channel 3 @ 2mA
# 	NEW_FIN_C = FIN_C - (Zero_offset / LSB)
# 	33181 = 33179 - (-110.626 nA / 67.978 nA)
# 	Offset after Cal = 76.532 nA
# FIN_I_M CALIBRATION for channel 3 @ 2mA
# 	NEW_FIN_I_M = FIN_I_M * (I_HIGH_SET / I_HIGH_MEAS)
# 	64710 = 64710 * (2.227 mA / 2.227 mA)
# 	V_MAX after Cal = 2.227 mA
# FIN_I_C CALIBRATION for channel 3 @ 2mA
# 	NEW_FIN_C = FIN_C - (Zero_offset / LSB)
# 	33180 = 33181 - (42.915 nA / 67.978 nA)
# 	Offset after Cal = -6.199 nA
# FIN_I_M CALIBRATION for channel 3 @ 2mA
# 	NEW_FIN_I_M = FIN_I_M * (I_HIGH_SET / I_HIGH_MEAS)
# 	64711 = 64710 * (2.227 mA / 2.227 mA)
# 	V_MAX after Cal = 2.227 mA
# FIN_I_C CALIBRATION for channel 3 @ 2mA
# 	NEW_FIN_C = FIN_C - (Zero_offset / LSB)
# 	33180 = 33180 - (15.736 nA / 67.978 nA)
# 	Offset after Cal = -20.504 nA
# FIN_I_M CALIBRATION for channel 3 @ 2mA
# 	NEW_FIN_I_M = FIN_I_M * (I_HIGH_SET / I_HIGH_MEAS)
# 	64711 = 64710 * (2.227 mA / 2.227 mA)
# 	V_MAX after Cal = 2.227 mA
# FIN_I_C CALIBRATION for channel 3 @ 2mA
# 	NEW_FIN_C = FIN_C - (Zero_offset / LSB)
# 	33180 = 33180 - (18.358 nA / 67.978 nA)
# 	Offset after Cal = -16.451 nA
# Calibration OK
# FIN_I_M CALIBRATION for channel 0 @ extA
# 	NEW_FIN_I_M = FIN_I_M * (I_HIGH_SET / I_HIGH_MEAS)
# 	64828 = 65535 * (74.248 mA / 75.057 mA)
# 	V_MAX after Cal = 73.437 mA
# FIN_I_C CALIBRATION for channel 0 @ extA
# 	NEW_FIN_C = FIN_C - (Zero_offset / LSB)
# 	33137 = 32768 - (-836.546 µA / 2.266 µA)
# 	Offset after Cal = 9.544 µA
# FIN_I_M CALIBRATION for channel 0 @ extA
# 	NEW_FIN_I_M = FIN_I_M * (I_HIGH_SET / I_HIGH_MEAS)
# 	64798 = 64828 * (74.248 mA / 74.282 mA)
# 	V_MAX after Cal = 74.216 mA
# FIN_I_C CALIBRATION for channel 0 @ extA
# 	NEW_FIN_C = FIN_C - (Zero_offset / LSB)
# 	33148 = 33137 - (-24.290 µA / 2.266 µA)
# 	Offset after Cal = 994.206 nA
# FIN_I_M CALIBRATION for channel 0 @ extA
# 	NEW_FIN_I_M = FIN_I_M * (I_HIGH_SET / I_HIGH_MEAS)
# 	64804 = 64798 * (74.248 mA / 74.241 mA)
# 	V_MAX after Cal = 74.258 mA
# FIN_I_C CALIBRATION for channel 0 @ extA
# 	NEW_FIN_C = FIN_C - (Zero_offset / LSB)
# 	33144 = 33148 - (8.206 µA / 2.266 µA)
# 	Offset after Cal = -1.116 µA
# FIN_I_M CALIBRATION for channel 0 @ extA
# 	NEW_FIN_I_M = FIN_I_M * (I_HIGH_SET / I_HIGH_MEAS)
# 	64805 = 64804 * (74.248 mA / 74.246 mA)
# 	V_MAX after Cal = 74.248 mA
# FIN_I_C CALIBRATION for channel 0 @ extA
# 	NEW_FIN_C = FIN_C - (Zero_offset / LSB)
# 	33145 = 33144 - (-1.574 µA / 2.266 µA)
# 	Offset after Cal = 557.899 nA
# FIN_I_M CALIBRATION for channel 0 @ extA
# 	NEW_FIN_I_M = FIN_I_M * (I_HIGH_SET / I_HIGH_MEAS)
# 	64803 = 64804 * (74.248 mA / 74.249 mA)
# 	V_MAX after Cal = 74.247 mA
# FIN_I_C CALIBRATION for channel 0 @ extA
# 	NEW_FIN_C = FIN_C - (Zero_offset / LSB)
# 	33146 = 33145 - (-1.264 µA / 2.266 µA)
# 	Offset after Cal = 1.113 µA
# FIN_I_M CALIBRATION for channel 0 @ extA
# 	NEW_FIN_I_M = FIN_I_M * (I_HIGH_SET / I_HIGH_MEAS)
# ...
# 	NEW_CLH_I_C = CLH_I_C - (Zero_offset / LSB)
# 	31191 = 31192 - (52.118 nA / 67.978 nA)
# 	Offset after Cal = -24.646 nA
# CLH_I_M CALIBRATION for channel 0 @ 2mA
# 	NEW_CLH_I_M = CLH_I_M * ((I_HIGH_SET / I_HIGH_MEAS) + 1) / 2
# 	64539 = 64538 * ((2.227 mA / 2.227 mA) + 1) / 2
# 	I_MAX after Cal = 2.227 mA
# CLH_I_C CALIBRATION for channel 0 @ 2mA
# 	NEW_CLH_I_C = CLH_I_C - (Zero_offset / LSB)
# 	31191 = 31191 - (-27.405 nA / 67.978 nA)
# 	Offset after Cal = -31.946 nA
# CLH_I_M CALIBRATION for channel 0 @ 2mA
# 	NEW_CLH_I_M = CLH_I_M * ((I_HIGH_SET / I_HIGH_MEAS) + 1) / 2
# 	64541 = 64538 * ((2.227 mA / 2.227 mA) + 1) / 2
# 	I_MAX after Cal = 2.227 mA
# CLH_I_C CALIBRATION for channel 0 @ 2mA
# 	NEW_CLH_I_C = CLH_I_C - (Zero_offset / LSB)
# 	31190 = 31191 - (54.476 nA / 67.978 nA)
# 	Offset after Cal = -16.210 nA
# CLH_I_M CALIBRATION for channel 0 @ 2mA
# 	NEW_CLH_I_M = CLH_I_M * ((I_HIGH_SET / I_HIGH_MEAS) + 1) / 2
# 	64542 = 64540 * ((2.227 mA / 2.227 mA) + 1) / 2
# 	I_MAX after Cal = 2.228 mA
# CLH_I_C CALIBRATION for channel 0 @ 2mA
# 	NEW_CLH_I_C = CLH_I_C - (Zero_offset / LSB)
# 	31189 = 31190 - (51.265 nA / 67.978 nA)
# 	Offset after Cal = -10.925 nA
# CLH_I_M CALIBRATION for channel 0 @ 2mA
# 	NEW_CLH_I_M = CLH_I_M * ((I_HIGH_SET / I_HIGH_MEAS) + 1) / 2
# 	64541 = 64542 * ((2.227 mA / 2.227 mA) + 1) / 2
# 	I_MAX after Cal = 2.227 mA
# CLH_I_C CALIBRATION for channel 0 @ 2mA
# 	NEW_CLH_I_C = CLH_I_C - (Zero_offset / LSB)
# 	31190 = 31189 - (-87.884 nA / 67.978 nA)
# 	Offset after Cal = -8.971 nA
# CLH_I_M CALIBRATION for channel 0 @ 2mA
# 	NEW_CLH_I_M = CLH_I_M * ((I_HIGH_SET / I_HIGH_MEAS) + 1) / 2
# 	64541 = 64540 * ((2.227 mA / 2.227 mA) + 1) / 2
# 	I_MAX after Cal = 2.227 mA
# CLH_I_C CALIBRATION for channel 0 @ 2mA
# 	NEW_CLH_I_C = CLH_I_C - (Zero_offset / LSB)
# 	31190 = 31190 - (-23.540 nA / 67.978 nA)
# 	Offset after Cal = -20.041 nA
# Calibration OK
# CLH_I_M CALIBRATION for channel 1 @ 2mA
# 	NEW_CLH_I_M = CLH_I_M * ((I_HIGH_SET / I_HIGH_MEAS) + 1) / 2
# 	63110 = 65535 * ((2.227 mA / 2.405 mA) + 1) / 2
# 	I_MAX after Cal = 2.238 mA
# CLH_I_C CALIBRATION for channel 1 @ 2mA
# 	NEW_CLH_I_C = CLH_I_C - (Zero_offset / LSB)
# 	31901 = 32768 - (58.946 µA / 67.978 nA)
# 	Offset after Cal = -932.295 nA
# CLH_I_M CALIBRATION for channel 1 @ 2mA
# 	NEW_CLH_I_M = CLH_I_M * ((I_HIGH_SET / I_HIGH_MEAS) + 1) / 2
# 	63827 = 63110 * ((2.227 mA / 2.178 mA) + 1) / 2
# 	I_MAX after Cal = 2.227 mA
# CLH_I_C CALIBRATION for channel 1 @ 2mA
# 	NEW_CLH_I_C = CLH_I_C - (Zero_offset / LSB)
# 	31551 = 31901 - (23.812 µA / 67.978 nA)
# 	Offset after Cal = -368.978 nA
# CLH_I_M CALIBRATION for channel 1 @ 2mA
# 	NEW_CLH_I_M = CLH_I_M * ((I_HIGH_SET / I_HIGH_MEAS) + 1) / 2
# 	64177 = 63826 * ((2.227 mA / 2.203 mA) + 1) / 2
# 	I_MAX after Cal = 2.227 mA
# CLH_I_C CALIBRATION for channel 1 @ 2mA
# 	NEW_CLH_I_C = CLH_I_C - (Zero_offset / LSB)
# 	31378 = 31551 - (11.729 µA / 67.978 nA)
# 	Offset after Cal = -239.105 nA
# CLH_I_M CALIBRATION for channel 1 @ 2mA
# 	NEW_CLH_I_M = CLH_I_M * ((I_HIGH_SET / I_HIGH_MEAS) + 1) / 2
# 	64350 = 64176 * ((2.227 mA / 2.215 mA) + 1) / 2
# 	I_MAX after Cal = 2.228 mA
# CLH_I_C CALIBRATION for channel 1 @ 2mA
# 	NEW_CLH_I_C = CLH_I_C - (Zero_offset / LSB)
# 	31293 = 31378 - (5.767 µA / 67.978 nA)
# 	Offset after Cal = -107.372 nA
# CLH_I_M CALIBRATION for channel 1 @ 2mA
# 	NEW_CLH_I_M = CLH_I_M * ((I_HIGH_SET / I_HIGH_MEAS) + 1) / 2
# 	64436 = 64350 * ((2.227 mA / 2.222 mA) + 1) / 2
# 	I_MAX after Cal = 2.228 mA
# CLH_I_C CALIBRATION for channel 1 @ 2mA
# 	NEW_CLH_I_C = CLH_I_C - (Zero_offset / LSB)
# 	31251 = 31293 - (2.875 µA / 67.978 nA)
# 	Offset after Cal = -33.121 nA
# CLH_I_M CALIBRATION for channel 1 @ 2mA
# 	NEW_CLH_I_M = CLH_I_M * ((I_HIGH_SET / I_HIGH_MEAS) + 1) / 2
# 	64475 = 64436 * ((2.227 mA / 2.225 mA) + 1) / 2
# 	I_MAX after Cal = 2.227 mA
# CLH_I_C CALIBRATION for channel 1 @ 2mA
# 	NEW_CLH_I_C = CLH_I_C - (Zero_offset / LSB)
# 	31232 = 31251 - (1.283 µA / 67.978 nA)
# 	Offset after Cal = -42.517 nA
# CLH_I_M CALIBRATION for channel 1 @ 2mA
# 	NEW_CLH_I_M = CLH_I_M * ((I_HIGH_SET / I_HIGH_MEAS) + 1) / 2
# 	64494 = 64474 * ((2.227 mA / 2.226 mA) + 1) / 2
# 	I_MAX after Cal = 2.227 mA
# CLH_I_C CALIBRATION for channel 1 @ 2mA
# 	NEW_CLH_I_C = CLH_I_C - (Zero_offset / LSB)
# 	31222 = 31232 - (652.340 nA / 67.978 nA)
# 	Offset after Cal = -42.622 nA
# CLH_I_M CALIBRATION for channel 1 @ 2mA
# 	NEW_CLH_I_M = CLH_I_M * ((I_HIGH_SET / I_HIGH_MEAS) + 1) / 2
# 	64504 = 64494 * ((2.227 mA / 2.227 mA) + 1) / 2
# 	I_MAX after Cal = 2.227 mA
# CLH_I_C CALIBRATION for channel 1 @ 2mA
# 	NEW_CLH_I_C = CLH_I_C - (Zero_offset / LSB)
# 	31217 = 31222 - (313.837 nA / 67.978 nA)
# 	Offset after Cal = -33.305 nA
# CLH_I_M CALIBRATION for channel 1 @ 2mA
# 	NEW_CLH_I_M = CLH_I_M * ((I_HIGH_SET / I_HIGH_MEAS) + 1) / 2
# 	64510 = 64504 * ((2.227 mA / 2.227 mA) + 1) / 2
# 	I_MAX after Cal = 2.227 mA
# CLH_I_C CALIBRATION for channel 1 @ 2mA
# 	NEW_CLH_I_C = CLH_I_C - (Zero_offset / LSB)
# 	31215 = 31217 - (169.682 nA / 67.978 nA)
# 	Offset after Cal = 33.093 nA
# CLH_I_M CALIBRATION for channel 1 @ 2mA
# 	NEW_CLH_I_M = CLH_I_M * ((I_HIGH_SET / I_HIGH_MEAS) + 1) / 2
# 	64512 = 64510 * ((2.227 mA / 2.227 mA) + 1) / 2
# 	I_MAX after Cal = 2.227 mA
# CLH_I_C CALIBRATION for channel 1 @ 2mA
# 	NEW_CLH_I_C = CLH_I_C - (Zero_offset / LSB)
# 	31214 = 31215 - (99.595 nA / 67.978 nA)
# 	Offset after Cal = 29.620 nA
# CLH_I_M CALIBRATION for channel 1 @ 2mA
# 	NEW_CLH_I_M = CLH_I_M * ((I_HIGH_SET / I_HIGH_MEAS) + 1) / 2
# 	64512 = 64512 * ((2.227 mA / 2.227 mA) + 1) / 2
# 	I_MAX after Cal = 2.227 mA
# CLH_I_C CALIBRATION for channel 1 @ 2mA
# 	NEW_CLH_I_C = CLH_I_C - (Zero_offset / LSB)
# 	31213 = 31214 - (36.881 nA / 67.978 nA)
# 	Offset after Cal = -42.233 nA
# CLH_I_M CALIBRATION for channel 1 @ 2mA
# 	NEW_CLH_I_M = CLH_I_M * ((I_HIGH_SET / I_HIGH_MEAS) + 1) / 2
# 	64512 = 64512 * ((2.227 mA / 2.227 mA) + 1) / 2
# 	I_MAX after Cal = 2.227 mA
# CLH_I_C CALIBRATION for channel 1 @ 2mA
# 	NEW_CLH_I_C = CLH_I_C - (Zero_offset / LSB)
# 	31214 = 31213 - (-37.041 nA / 67.978 nA)
# 	Offset after Cal = 36.176 nA
# CLH_I_M CALIBRATION for channel 1 @ 2mA
# 	NEW_CLH_I_M = CLH_I_M * ((I_HIGH_SET / I_HIGH_MEAS) + 1) / 2
# 	64512 = 64512 * ((2.227 mA / 2.227 mA) + 1) / 2
# 	I_MAX after Cal = 2.227 mA
# CLH_I_C CALIBRATION for channel 1 @ 2mA
# 	NEW_CLH_I_C = CLH_I_C - (Zero_offset / LSB)
# 	31213 = 31214 - (35.286 nA / 67.978 nA)
# 	Offset after Cal = -32.480 nA
# CLH_I_M CALIBRATION for channel 1 @ 2mA
# 	NEW_CLH_I_M = CLH_I_M * ((I_HIGH_SET / I_HIGH_MEAS) + 1) / 2
# 	64513 = 64512 * ((2.227 mA / 2.227 mA) + 1) / 2
# 	I_MAX after Cal = 2.227 mA
# CLH_I_C CALIBRATION for channel 1 @ 2mA
# 	NEW_CLH_I_C = CLH_I_C - (Zero_offset / LSB)
# 	31214 = 31213 - (-44.781 nA / 67.978 nA)
# 	Offset after Cal = 18.812 nA
# CLH_I_M CALIBRATION for channel 1 @ 2mA
# 	NEW_CLH_I_M = CLH_I_M * ((I_HIGH_SET / I_HIGH_MEAS) + 1) / 2
# 	64512 = 64512 * ((2.227 mA / 2.227 mA) + 1) / 2
# 	I_MAX after Cal = 2.227 mA
# CLH_I_C CALIBRATION for channel 1 @ 2mA
# 	NEW_CLH_I_C = CLH_I_C - (Zero_offset / LSB)
# 	31214 = 31214 - (29.833 nA / 67.978 nA)
# 	Offset after Cal = 43.324 nA
# CLH_I_M CALIBRATION for channel 1 @ 2mA
# 	NEW_CLH_I_M = CLH_I_M * ((I_HIGH_SET / I_HIGH_MEAS) + 1) / 2
# 	64512 = 64512 * ((2.227 mA / 2.227 mA) + 1) / 2
# 	I_MAX after Cal = 2.227 mA
# CLH_I_C CALIBRATION for channel 1 @ 2mA
# 	NEW_CLH_I_C = CLH_I_C - (Zero_offset / LSB)
# 	31213 = 31214 - (36.614 nA / 67.978 nA)
# 	Offset after Cal = -42.764 nA
# CLH_I_M CALIBRATION for channel 1 @ 2mA
# 	NEW_CLH_I_M = CLH_I_M * ((I_HIGH_SET / I_HIGH_MEAS) + 1) / 2
# 	64512 = 64512 * ((2.227 mA / 2.227 mA) + 1) / 2
# 	I_MAX after Cal = 2.227 mA
# CLH_I_C CALIBRATION for channel 1 @ 2mA
# 	NEW_CLH_I_C = CLH_I_C - (Zero_offset / LSB)
# 	31213 = 31213 - (-30.118 nA / 67.978 nA)
# 	Offset after Cal = -34.685 nA
# Calibration OK
# CLH_I_M CALIBRATION for channel 2 @ 2mA
# 	NEW_CLH_I_M = CLH_I_M * ((I_HIGH_SET / I_HIGH_MEAS) + 1) / 2
# 	63160 = 65535 * ((2.227 mA / 2.402 mA) + 1) / 2
# 	I_MAX after Cal = 2.237 mA
# CLH_I_C CALIBRATION for channel 2 @ 2mA
# 	NEW_CLH_I_C = CLH_I_C - (Zero_offset / LSB)
# 	31920 = 32768 - (57.661 µA / 67.978 nA)
# 	Offset after Cal = -861.825 nA
# CLH_I_M CALIBRATION for channel 2 @ 2mA
# 	NEW_CLH_I_M = CLH_I_M * ((I_HIGH_SET / I_HIGH_MEAS) + 1) / 2
# 	63864 = 63160 * ((2.227 mA / 2.179 mA) + 1) / 2
# 	I_MAX after Cal = 2.228 mA
# CLH_I_C CALIBRATION for channel 2 @ 2mA
# 	NEW_CLH_I_C = CLH_I_C - (Zero_offset / LSB)
# 	31575 = 31920 - (23.433 µA / 67.978 nA)
# 	Offset after Cal = -398.680 nA
# CLH_I_M CALIBRATION for channel 2 @ 2mA
# 	NEW_CLH_I_M = CLH_I_M * ((I_HIGH_SET / I_HIGH_MEAS) + 1) / 2
# 	64209 = 63864 * ((2.227 mA / 2.204 mA) + 1) / 2
# 	I_MAX after Cal = 2.228 mA
# CLH_I_C CALIBRATION for channel 2 @ 2mA
# 	NEW_CLH_I_C = CLH_I_C - (Zero_offset / LSB)
# 	31406 = 31575 - (11.475 µA / 67.978 nA)
# 	Offset after Cal = -184.470 nA
# CLH_I_M CALIBRATION for channel 2 @ 2mA
# 	NEW_CLH_I_M = CLH_I_M * ((I_HIGH_SET / I_HIGH_MEAS) + 1) / 2
# 	64378 = 64208 * ((2.227 mA / 2.216 mA) + 1) / 2
# 	I_MAX after Cal = 2.228 mA
# CLH_I_C CALIBRATION for channel 2 @ 2mA
# 	NEW_CLH_I_C = CLH_I_C - (Zero_offset / LSB)
# 	31323 = 31406 - (5.675 µA / 67.978 nA)
# 	Offset after Cal = -49.072 nA
# CLH_I_M CALIBRATION for channel 2 @ 2mA
# 	NEW_CLH_I_M = CLH_I_M * ((I_HIGH_SET / I_HIGH_MEAS) + 1) / 2
# 	64460 = 64378 * ((2.227 mA / 2.222 mA) + 1) / 2
# 	I_MAX after Cal = 2.227 mA
# CLH_I_C CALIBRATION for channel 2 @ 2mA
# 	NEW_CLH_I_C = CLH_I_C - (Zero_offset / LSB)
# 	31282 = 31323 - (2.771 µA / 67.978 nA)
# 	Offset after Cal = -46.996 nA
# CLH_I_M CALIBRATION for channel 2 @ 2mA
# 	NEW_CLH_I_M = CLH_I_M * ((I_HIGH_SET / I_HIGH_MEAS) + 1) / 2
# 	64501 = 64460 * ((2.227 mA / 2.225 mA) + 1) / 2
# 	I_MAX after Cal = 2.227 mA
# CLH_I_C CALIBRATION for channel 2 @ 2mA
# 	NEW_CLH_I_C = CLH_I_C - (Zero_offset / LSB)
# 	31263 = 31282 - (1.323 µA / 67.978 nA)
# 	Offset after Cal = 25.106 nA
# CLH_I_M CALIBRATION for channel 2 @ 2mA
# 	NEW_CLH_I_M = CLH_I_M * ((I_HIGH_SET / I_HIGH_MEAS) + 1) / 2
# 	64520 = 64500 * ((2.227 mA / 2.226 mA) + 1) / 2
# 	I_MAX after Cal = 2.228 mA
# CLH_I_C CALIBRATION for channel 2 @ 2mA
# 	NEW_CLH_I_C = CLH_I_C - (Zero_offset / LSB)
# 	31253 = 31263 - (703.911 nA / 67.978 nA)
# 	Offset after Cal = 21.126 nA
# CLH_I_M CALIBRATION for channel 2 @ 2mA
# 	NEW_CLH_I_M = CLH_I_M * ((I_HIGH_SET / I_HIGH_MEAS) + 1) / 2
# 	64529 = 64520 * ((2.227 mA / 2.227 mA) + 1) / 2
# 	I_MAX after Cal = 2.227 mA
# CLH_I_C CALIBRATION for channel 2 @ 2mA
# 	NEW_CLH_I_C = CLH_I_C - (Zero_offset / LSB)
# 	31249 = 31253 - (291.197 nA / 67.978 nA)
# 	Offset after Cal = 14.278 nA
# CLH_I_M CALIBRATION for channel 2 @ 2mA
# 	NEW_CLH_I_M = CLH_I_M * ((I_HIGH_SET / I_HIGH_MEAS) + 1) / 2
# 	64534 = 64528 * ((2.227 mA / 2.227 mA) + 1) / 2
# 	I_MAX after Cal = 2.227 mA
# CLH_I_C CALIBRATION for channel 2 @ 2mA
# 	NEW_CLH_I_C = CLH_I_C - (Zero_offset / LSB)
# 	31246 = 31249 - (225.106 nA / 67.978 nA)
# 	Offset after Cal = 27.507 nA
# CLH_I_M CALIBRATION for channel 2 @ 2mA
# 	NEW_CLH_I_M = CLH_I_M * ((I_HIGH_SET / I_HIGH_MEAS) + 1) / 2
# 	64536 = 64534 * ((2.227 mA / 2.227 mA) + 1) / 2
# 	I_MAX after Cal = 2.227 mA
# CLH_I_C CALIBRATION for channel 2 @ 2mA
# 	NEW_CLH_I_C = CLH_I_C - (Zero_offset / LSB)
# 	31245 = 31246 - (79.684 nA / 67.978 nA)
# 	Offset after Cal = 26.935 nA
# CLH_I_M CALIBRATION for channel 2 @ 2mA
# 	NEW_CLH_I_M = CLH_I_M * ((I_HIGH_SET / I_HIGH_MEAS) + 1) / 2
# 	64538 = 64536 * ((2.227 mA / 2.227 mA) + 1) / 2
# 	I_MAX after Cal = 2.227 mA
# CLH_I_C CALIBRATION for channel 2 @ 2mA
# 	NEW_CLH_I_C = CLH_I_C - (Zero_offset / LSB)
# 	31244 = 31245 - (85.289 nA / 67.978 nA)
# 	Offset after Cal = 12.208 nA
# CLH_I_M CALIBRATION for channel 2 @ 2mA
# 	NEW_CLH_I_M = CLH_I_M * ((I_HIGH_SET / I_HIGH_MEAS) + 1) / 2
# 	64539 = 64538 * ((2.227 mA / 2.227 mA) + 1) / 2
# 	I_MAX after Cal = 2.227 mA
# CLH_I_C CALIBRATION for channel 2 @ 2mA
# 	NEW_CLH_I_C = CLH_I_C - (Zero_offset / LSB)
# 	31244 = 31244 - (6.974 nA / 67.978 nA)
# 	Offset after Cal = 13.829 nA
# CLH_I_M CALIBRATION for channel 2 @ 2mA
# 	NEW_CLH_I_M = CLH_I_M * ((I_HIGH_SET / I_HIGH_MEAS) + 1) / 2
# 	64539 = 64538 * ((2.227 mA / 2.227 mA) + 1) / 2
# 	I_MAX after Cal = 2.227 mA
# CLH_I_C CALIBRATION for channel 2 @ 2mA
# 	NEW_CLH_I_C = CLH_I_C - (Zero_offset / LSB)
# 	31244 = 31244 - (15.074 nA / 67.978 nA)
# 	Offset after Cal = 14.875 nA
# Calibration OK
# CLH_I_M CALIBRATION for channel 3 @ 2mA
# 	NEW_CLH_I_M = CLH_I_M * ((I_HIGH_SET / I_HIGH_MEAS) + 1) / 2
# 	63130 = 65535 * ((2.227 mA / 2.404 mA) + 1) / 2
# 	I_MAX after Cal = 2.238 mA
# CLH_I_C CALIBRATION for channel 3 @ 2mA
# 	NEW_CLH_I_C = CLH_I_C - (Zero_offset / LSB)
# 	31925 = 32768 - (57.336 µA / 67.978 nA)
# 	Offset after Cal = -887.175 nA
# CLH_I_M CALIBRATION for channel 3 @ 2mA
# 	NEW_CLH_I_M = CLH_I_M * ((I_HIGH_SET / I_HIGH_MEAS) + 1) / 2
# 	63827 = 63130 * ((2.227 mA / 2.179 mA) + 1) / 2
# 	I_MAX after Cal = 2.228 mA
# CLH_I_C CALIBRATION for channel 3 @ 2mA
# 	NEW_CLH_I_C = CLH_I_C - (Zero_offset / LSB)
# 	31584 = 31925 - (23.152 µA / 67.978 nA)
# 	Offset after Cal = -393.344 nA
# CLH_I_M CALIBRATION for channel 3 @ 2mA
# 	NEW_CLH_I_M = CLH_I_M * ((I_HIGH_SET / I_HIGH_MEAS) + 1) / 2
# 	64169 = 63826 * ((2.227 mA / 2.204 mA) + 1) / 2
# 	I_MAX after Cal = 2.228 mA
# CLH_I_C CALIBRATION for channel 3 @ 2mA
# 	NEW_CLH_I_C = CLH_I_C - (Zero_offset / LSB)
# 	31416 = 31584 - (11.416 µA / 67.978 nA)
# 	Offset after Cal = -182.523 nA
# CLH_I_M CALIBRATION for channel 3 @ 2mA
# 	NEW_CLH_I_M = CLH_I_M * ((I_HIGH_SET / I_HIGH_MEAS) + 1) / 2
# 	64336 = 64168 * ((2.227 mA / 2.216 mA) + 1) / 2
# 	I_MAX after Cal = 2.228 mA
# CLH_I_C CALIBRATION for channel 3 @ 2mA
# 	NEW_CLH_I_C = CLH_I_C - (Zero_offset / LSB)
# 	31333 = 31416 - (5.609 µA / 67.978 nA)
# 	Offset after Cal = -111.547 nA
# CLH_I_M CALIBRATION for channel 3 @ 2mA
# 	NEW_CLH_I_M = CLH_I_M * ((I_HIGH_SET / I_HIGH_MEAS) + 1) / 2
# 	64419 = 64336 * ((2.227 mA / 2.222 mA) + 1) / 2
# 	I_MAX after Cal = 2.228 mA
# CLH_I_C CALIBRATION for channel 3 @ 2mA
# 	NEW_CLH_I_C = CLH_I_C - (Zero_offset / LSB)
# 	31293 = 31333 - (2.711 µA / 67.978 nA)
# 	Offset after Cal = -48.550 nA
# CLH_I_M CALIBRATION for channel 3 @ 2mA
# 	NEW_CLH_I_M = CLH_I_M * ((I_HIGH_SET / I_HIGH_MEAS) + 1) / 2
# 	64457 = 64418 * ((2.227 mA / 2.225 mA) + 1) / 2
# 	I_MAX after Cal = 2.227 mA
# CLH_I_C CALIBRATION for channel 3 @ 2mA
# 	NEW_CLH_I_C = CLH_I_C - (Zero_offset / LSB)
# 	31274 = 31293 - (1.258 µA / 67.978 nA)
# 	Offset after Cal = -51.860 nA
# CLH_I_M CALIBRATION for channel 3 @ 2mA
# 	NEW_CLH_I_M = CLH_I_M * ((I_HIGH_SET / I_HIGH_MEAS) + 1) / 2
# 	64477 = 64456 * ((2.227 mA / 2.226 mA) + 1) / 2
# 	I_MAX after Cal = 2.227 mA
# CLH_I_C CALIBRATION for channel 3 @ 2mA
# 	NEW_CLH_I_C = CLH_I_C - (Zero_offset / LSB)
# 	31265 = 31274 - (640.521 nA / 67.978 nA)
# 	Offset after Cal = 15.107 nA
# CLH_I_M CALIBRATION for channel 3 @ 2mA
# 	NEW_CLH_I_M = CLH_I_M * ((I_HIGH_SET / I_HIGH_MEAS) + 1) / 2
# 	64486 = 64476 * ((2.227 mA / 2.227 mA) + 1) / 2
# 	I_MAX after Cal = 2.227 mA
# CLH_I_C CALIBRATION for channel 3 @ 2mA
# 	NEW_CLH_I_C = CLH_I_C - (Zero_offset / LSB)
# 	31260 = 31265 - (367.736 nA / 67.978 nA)
# 	Offset after Cal = 20.768 nA
# CLH_I_M CALIBRATION for channel 3 @ 2mA
# 	NEW_CLH_I_M = CLH_I_M * ((I_HIGH_SET / I_HIGH_MEAS) + 1) / 2
# 	64491 = 64486 * ((2.227 mA / 2.227 mA) + 1) / 2
# 	I_MAX after Cal = 2.227 mA
# CLH_I_C CALIBRATION for channel 3 @ 2mA
# 	NEW_CLH_I_C = CLH_I_C - (Zero_offset / LSB)
# 	31258 = 31260 - (169.122 nA / 67.978 nA)
# 	Offset after Cal = 26.134 nA
# CLH_I_M CALIBRATION for channel 3 @ 2mA
# 	NEW_CLH_I_M = CLH_I_M * ((I_HIGH_SET / I_HIGH_MEAS) + 1) / 2
# 	64493 = 64490 * ((2.227 mA / 2.227 mA) + 1) / 2
# 	I_MAX after Cal = 2.227 mA
# CLH_I_C CALIBRATION for channel 3 @ 2mA
# 	NEW_CLH_I_C = CLH_I_C - (Zero_offset / LSB)
# 	31257 = 31258 - (92.843 nA / 67.978 nA)
# 	Offset after Cal = 25.425 nA
# CLH_I_M CALIBRATION for channel 3 @ 2mA
# 	NEW_CLH_I_M = CLH_I_M * ((I_HIGH_SET / I_HIGH_MEAS) + 1) / 2
# 	64495 = 64492 * ((2.227 mA / 2.227 mA) + 1) / 2
# 	I_MAX after Cal = 2.227 mA
# CLH_I_C CALIBRATION for channel 3 @ 2mA
# 	NEW_CLH_I_C = CLH_I_C - (Zero_offset / LSB)
# 	31256 = 31257 - (91.776 nA / 67.978 nA)
# 	Offset after Cal = 17.508 nA
# CLH_I_M CALIBRATION for channel 3 @ 2mA
# 	NEW_CLH_I_M = CLH_I_M * ((I_HIGH_SET / I_HIGH_MEAS) + 1) / 2
# 	64495 = 64494 * ((2.227 mA / 2.227 mA) + 1) / 2
# 	I_MAX after Cal = 2.227 mA
# CLH_I_C CALIBRATION for channel 3 @ 2mA
# 	NEW_CLH_I_C = CLH_I_C - (Zero_offset / LSB)
# 	31256 = 31256 - (19.719 nA / 67.978 nA)
# 	Offset after Cal = -27.836 pA
# Calibration OK

# %%
print("C")
C = p.read_dac_regs(reg="C")
C
# Out:
# C
#    FIN_I_5u  FIN_I_20u  FIN_I_200u  FIN_I_2m  FIN_I_ext  FIN_U  CLL_I  CLL_U  \
# 0     33210      33155       33186     33164      33147  32924  34962  33103
# 1     33213      33163       33185     33169      33173  32946  35028  33136
# 2     33232      33184       33209     33182      33189  32938  35026  33157
# 3     33227      33176       33203     33180      33176  32913  35085  33175
#
#    CLH_I  CLH_U
# 0  31190  32643
# 1  31213  32651
# 2  31244  32645
# 3  31256  32645

# %%
print("M")
M = p.read_dac_regs(reg="M")
M
# Out:
# M
#    FIN_I_5u  FIN_I_20u  FIN_I_200u  FIN_I_2m  FIN_I_ext  FIN_U  CLL_I  CLL_U  \
# 0     64666      64740       64718     64730      64800  64852  64654  64874
# 1     64646      64708       64704     64702      64732  64860  64594  64872
# 2     64690      64748       64738     64758      64782  64856  64658  64872
# 3     64646      64710       64696     64710      64750  64856  64606  64882
#
#    CLH_I  CLH_U
# 0  64540  64864
# 1  64512  64872
# 2  64538  64860
# 3  64494  64858

# %%
# test for cal
set_range = "ext"
ch = 0
points = 3
reset = True

#for debug:
p.c.com_delay = 0

fig, axs = plt.subplots(2, sharex=True)
if set_range == "v":
    fig.suptitle("Force Voltage for CH%i" % ch)
else:
    fig.suptitle("Force Current - %s for CH%i" % (set_range, ch))

if reset:
    p.reset()
    i = 1
    c_ok = False
    m_ok = False

# cal_data = pmu_cal.calibrate(p,k)

for i_iter in range(15):
    print(i)
    if set_range == "v":
        if i_iter == 0:
            reg_m = p.channels[ch].read_dac("FIN_U", "M")
            reg_c = p.channels[ch].read_dac("FIN_U", "C")
            x = p.channels[ch].read_dac("FIN_U", "M")
        elif i_iter%2 == 1:
            reg_m = pmu_cal.cal_FIN_U_M(p,k,ch)
        else:
            reg_c = pmu_cal.cal_FIN_U_C(p,k,ch)
        o, m = pmu_cal.measureFV(p, k, ch, points)
    else:
        if i_iter == 0:
            reg_m = p.channels[ch].read_dac("FIN_I_"+set_range, "M")
            reg_c = p.channels[ch].read_dac("FIN_I_"+set_range, "C")
        elif i_iter%2 == 1:
            reg_m = pmu_cal.cal_FIN_I_M(p,k,ch,set_range)
        else:
            reg_c = pmu_cal.cal_FIN_I_C(p,k,ch,set_range)
        o, m = pmu_cal.measureFI(p, k, ch, set_range, points)
        m = -m
    if i_iter > 0:
        i+=1
    
    
    if (i_iter%2 == 1):
        if abs(last_reg_m-reg_m) <= 1:
            print("\n\nM OK\n\n")
            m_ok = True
        else:
            m_ok = False
    elif i_iter>0:
        if abs(last_reg_c-reg_c) <= 1:
            print("\n\nC OK\n\n")
            c_ok = True
        else:
            c_ok = False
            
    if c_ok and m_ok:
        print("CALIBRATION OK - breaking loop")
        break
    last_reg_m = reg_m
    last_reg_c = reg_c
        
    axs[0].plot(o, m, label="i=%i M=0x%04X C=0x%04X"%(i, reg_m, reg_c))
    axs[1].plot(o, (o-m), 'o')
    b,a = np.polyfit(o, (o-m), 1)
    axs[1].plot(o, b*o+a, ':k')
    
    # axs[1].plot(o, (o-m)/o*100)

axs[0].set_ylabel("Measured")
axs[0].grid(visible=True)
axs[0].legend()
axs[1].set_xlabel("Set_level")
# axs[1].set_ylabel("Error (%)")
axs[1].set_ylabel("Error")
# axs[1].set_ylim([-1, 1])
axs[1].grid(visible=True)
plt.show()
# Out:
# 1
# 1
# FIN_I_M CALIBRATION for channel 0 @ extA
# 	NEW_FIN_I_M = FIN_I_M * (I_HIGH_SET / I_HIGH_MEAS)
# 	64811 = 65535 * (74.248 mA / 75.077 mA)
# 	V_MAX after Cal = 73.415 mA
# 2
# FIN_I_C CALIBRATION for channel 0 @ extA
# 	NEW_FIN_C = FIN_C - (Zero_offset / LSB)
# 	33150 = 32768 - (-865.612 µA / 2.266 µA)
# 	Offset after Cal = 9.418 µA
# 3
# FIN_I_M CALIBRATION for channel 0 @ extA
# 	NEW_FIN_I_M = FIN_I_M * (I_HIGH_SET / I_HIGH_MEAS)
# 	64773 = 64810 * (74.248 mA / 74.290 mA)
# 	V_MAX after Cal = 74.205 mA
# 4
# FIN_I_C CALIBRATION for channel 0 @ extA
# 	NEW_FIN_C = FIN_C - (Zero_offset / LSB)
# 	33165 = 33150 - (-33.903 µA / 2.266 µA)
# 	Offset after Cal = 391.007 nA
# 5
# FIN_I_M CALIBRATION for channel 0 @ extA
# 	NEW_FIN_I_M = FIN_I_M * (I_HIGH_SET / I_HIGH_MEAS)
# 	64780 = 64772 * (74.248 mA / 74.239 mA)
# 	V_MAX after Cal = 74.259 mA
# 6
# FIN_I_C CALIBRATION for channel 0 @ extA
# 	NEW_FIN_C = FIN_C - (Zero_offset / LSB)
# 	33161 = 33165 - (9.460 µA / 2.266 µA)
# 	Offset after Cal = 224.113 nA
# 7
# FIN_I_M CALIBRATION for channel 0 @ extA
# 	NEW_FIN_I_M = FIN_I_M * (I_HIGH_SET / I_HIGH_MEAS)
# 	64780 = 64780 * (74.248 mA / 74.248 mA)
# 	V_MAX after Cal = 74.250 mA
#
#
# M OK
#
#
# 8
# FIN_I_C CALIBRATION for channel 0 @ extA
# 	NEW_FIN_C = FIN_C - (Zero_offset / LSB)
# 	33161 = 33161 - (550.747 nA / 2.266 µA)
# 	Offset after Cal = 371.933 nA
#
#
# C OK
#
#
# CALIBRATION OK - breaking loop

# %%
# test for reg-function
set_range = "5u"
ch = 0
points = 10

#for debug:
p.c.com_delay = 0
p.reset()

fig, axs = plt.subplots(2, sharex=True)
if set_range == "v":
    fig.suptitle("Force Voltage")
else:
    fig.suptitle("Force Current - %s" % set_range)

# for x in [0xFFFF, 0xFE00, 0xFC00, 0xFA00, 0xF800, 0xF600, 0xF400, 0xF200, 0xF000]:
for x in [0xFFFF, 0xFF00, 0xFE00]:
    if set_range == "v":
        p.channels[ch].write_dac(data = x, dac_reg = "FIN_U", reg = "M")
        o, m = pmu_cal.measureFV(p, k, ch, points)
    else:
        p.channels[ch].write_dac(data = x, dac_reg = "FIN_I_"+set_range, reg = "M")
        o, m = pmu_cal.measureFI(p, k, ch, set_range, points)
        m = -m
    axs[0].plot(o, m, label="ch%i, M=0x%04X"%(ch, x))
    axs[1].plot(o, (o-m), 'o', label="ch%i"%ch)
    b,a = np.polyfit(o, (o-m), 1)
    axs[1].plot(o, b*o+a, ':k')
    
    # axs[1].plot(o, (o-m)/o*100)

axs[0].set_ylabel("Measured")
axs[0].grid(visible=True)
axs[0].legend()
axs[1].set_xlabel("Set_level")
# axs[1].set_ylabel("Error (%)")
axs[1].set_ylabel("Error")
# axs[1].set_ylim([-1, 1])
axs[1].grid(visible=True)
plt.show()

# %%
# FV and FI-Error with raw force voltage
p.write_all_PMU_REGS(0x1E060)
p.c.verbose = False

points = 100

# print("Measure FV")

fig, axs = plt.subplots(2, sharex=True)
fig.suptitle("Force Voltage")
for ch in range(4):
# for ch in [0]:
    
    o, m = pmu_cal.measureFV(p, k, ch, points)
    axs[0].plot(o, m, label="ch%i"%ch)
    # axs[1].plot(o, (o-m)/o*100)
    if ch != 3:
        axs[1].plot(o, (o-m), label="ch%i"%ch)

axs[0].set_ylabel("Measured")
axs[0].grid(visible=True)
axs[0].legend()
axs[1].set_xlabel("Set_level")
# axs[1].set_ylabel("Error (%)")
axs[1].set_ylabel("Error")
# axs[1].set_ylim([-1, 1])
axs[1].grid(visible=True)
plt.show()

for i_range in pmu_def.I_RANGES:
    fig, axs = plt.subplots(2, sharex=True)
    fig.suptitle("Force Current - %s" % i_range)
    
    for ch in range(4):
    # for ch in [0]:
        o, m = pmu_cal.measureFI(p, k, ch, i_range, points)
        axs[0].plot(o, -m, label="ch%i"%ch)
        # axs[1].plot(o, (o-m)/o*100)
        axs[1].plot(o, (o+m), label="ch%i"%ch)

    axs[0].set_ylabel("Measured")
    axs[0].grid(visible=True)
    axs[0].legend()
    axs[1].set_xlabel("Set_level")
    # axs[1].set_ylabel("Error (%)")
    axs[1].set_ylabel("Error")
    # axs[1].set_ylim([-1, 1])
    axs[1].grid(visible=True)
    plt.show()

# %%
# FV and FI-Error
p.write_all_PMU_REGS(0x1E060)
measure_delay = 0.1

points = 100

for ch in range(4):
# for ch in [0]:    
    o, m = pmu_cal.measureFV(p, k, ch, points, measure_delay=measure_delay)

    # if ch != 3:
    #     plt.plot(o, (o-m), label="ch%i"%ch)
    plt.plot(o, (o-m), label="ch%i"%ch)

plt.title("Force Voltage")
plt.legend()
plt.xlabel("Set_level")
# axs[1].set_ylabel("Error (%)")
plt.ylabel("Error[V]")
plt.grid()
plt.show()

for i_range in pmu_def.I_RANGES:
# for i_range in ["5u"]:
    for ch in range(4):
    # for ch in [0]:
        o, m = pmu_cal.measureFI(p, k, ch, i_range, points, measure_delay=measure_delay)
        plt.plot(o, (o+m), label="ch%i"%ch)

    plt.title("Force Current - %s" % i_range)
    plt.legend()
    plt.xlabel("Set_level")
    plt.ylabel("Error (A)")
    plt.grid()
    plt.show()

# %% [markdown]
# # Memory interaction

# %%
# create Data for Memory and write to memory

mem_wr_list = dict()
for ch in range(4):
    for c_m in range(2):
        for i, reg_name in enumerate(list(pmu_def.DAC_REG_TABLE.keys())[1:]):
            adr = 0
            adr |= ch << 6
            adr |= c_m << 5
            adr |= i << 1
            if c_m:

                mem_wr_list[adr] = C.loc[ch, reg_name]
                # mem_list[adr] = "%i C %s" %(ch, reg_name)
            else:
                mem_wr_list[adr] = M.loc[ch, reg_name]
                # mem_list[adr] = "%i M %s" %(ch, reg_name)
        
        adr |= 0x1F
        adr -= 1
        # mem_list[adr] = X1.loc[ch, "Offset"]
        # mem_wr_list[adr] = 0xA492
        mem_wr_list[adr] = offset_val
        # mem_list[adr] = "%i offset" %(ch)

p.mem_write_data(mem_wr_list)
# mem_wr_list

# %%
#check if wr == rd
mem_rd_list = p.mem_read_data(list(mem_wr_list.keys()))

for adr in mem_wr_list.keys():
    if mem_wr_list[adr] != mem_rd_list[adr]:
        print("error @ adr %i - w=%i r=%i" % (
            adr,
            mem_wr_list[adr],
            mem_rd_list[adr]
        ))

# %%
#######################
#### caldata mem to pmu
#######################

#create adr list
adr_list = list()
for ch in range(4):
    for c_m in range(2):
        for i, reg_name in enumerate(list(pmu_def.DAC_REG_TABLE.keys())[1:]):
            adr = 0
            adr |= ch << 6
            adr |= c_m << 5
            adr |= i << 1
            adr_list.append(adr)
        
        adr |= 0x1F
        adr -= 1
        adr_list.append(adr)

#read data from memory
rd_cal_list = p.mem_read_data(adr_list)


#write data do dac reg
for ch in range(4):
    for c_m in range(2):
        for i, reg_name in enumerate(list(pmu_def.DAC_REG_TABLE.keys())[1:]):
            adr = 0
            adr |= ch << 6
            adr |= c_m << 5
            adr |= i << 1
            
            # print("ch:%i adr:%s reg:%s data:%i" %(
            #     ch,
            #     reg_name,
            #     ("C" if c_m else "M"),
            #     rd_cal_list[adr]
            # ))
            
            if c_m:
                p.channels[ch].write_dac(rd_cal_list[adr], reg_name, reg="C")
            else:
                p.channels[ch].write_dac(rd_cal_list[adr], reg_name, reg="M")
            
            sleep(0.1)
        adr |= 0x1F
        adr -= 1
        # mem_list[adr] = X1.loc[ch, "Offset"]
        p.channels[ch].write_dac(rd_cal_list[adr], "Offset")
        sleep(0.1)

# %%
M_recal = p.read_dac_regs(reg="M")
C_recal = p.read_dac_regs(reg="C")

# %% [markdown]
# # test for Clamps

# %%
# voltage clamp
num = 100
ol=0.1
measure_delay = 0.1

for ch in range(4):
# for ch in [0]:
    for r in pmu_def.I_RANGES:
    # for r in ["2m"]:

        set_vh ,meas_vh = pmu_cal.measureCL_U(p, k, ch, r, clamp_side='H', num=num, overlap=ol, measure_delay=measure_delay)
        plt.plot(set_vh, (set_vh-meas_vh), label="CLH_U @ %s" % r)
        
        set_vl ,meas_vl = pmu_cal.measureCL_U(p, k, ch, r, clamp_side='L', num=num, overlap=ol, measure_delay=measure_delay)
        plt.plot(set_vl, (set_vl-meas_vl), label="CLL_U @ %s" % r)

    plt.title("Force-I - V-Clamp - CH%i" % ch)
    plt.xlabel("Set_V [V]")
    plt.ylabel("Error")
    plt.legend()

    plt.show()

# %%
# current clamp ext
num = 100
measure_delay = 0.1
ol = 0.1
voltage=5

rel_max = True

for ch in range(4):
# for ch in [0]:
    # for r in pmu_def.I_RANGES:
    # for r in pmu_def.I_RANGES[:-1]:
    # for r in ["20u"]:
    for r in ["ext"]:
        max_val = pmu_def.CURRENT_RANGES[r]["MaxVal"]
        
        set_vh ,meas_vh = pmu_cal.measureCL_I(p, k, ch, r, clamp_side='H', voltage=voltage, overlap=ol, num=num, measure_delay=measure_delay)
        if rel_max:
            set_vh = set_vh/max_val
            meas_vh = meas_vh/max_val
        plt.plot(set_vh, (set_vh+meas_vh), label="CLH_U @ %s" % r)
        
        set_vl ,meas_vl = pmu_cal.measureCL_I(p, k, ch, r, clamp_side='L', voltage=voltage, overlap=ol, num=num, measure_delay=measure_delay)
        if rel_max:
            set_vl = set_vl/max_val
            meas_vl = meas_vl/max_val
        plt.plot(set_vl, (set_vl+meas_vl), label="CLL_U @ %s" % r)

    plt.title("Force-V - I-Clamp - CH%i" % ch)
    plt.xlabel("Set_I / MaxVal(I_range)")
    plt.ylabel("Error (meas / max)")
    plt.legend()

    plt.show()

# %%
#Clamp Calibration
ch = 0
r  = "2m"
cs = "L"
num = 3


p.channels[ch].write_dac(0xffff, "CL%s_I" % cs, "M")
p.channels[ch].write_dac(0x8000, "CL%s_I" % cs, "C")


set_vh ,meas_vh = pmu_cal.measureCL_I(p, k, ch, r, clamp_side=cs, num=num)
plt.plot(set_vh, (set_vh+meas_vh), label="CL%s_I @ %s #init" % (cs, r))

# p.channels[ch].write_dac(0xfC00, "CLH_I", "M")
# p.channels[ch].write_dac(0x7a40, "CLH_I", "C")
for i in range(3):
    pmu_cal.cal_CL_I_M(p,k,ch,r,cs)
    set_vh ,meas_vh = pmu_cal.measureCL_I(p, k, ch, r, clamp_side=cs, num=num)
    plt.plot(set_vh, (set_vh+meas_vh), label="CL%s_U @ %s #%i" % (cs, r, (i*2)))
    
    pmu_cal.cal_CL_I_C(p,k,ch,r,cs)
    set_vh ,meas_vh = pmu_cal.measureCL_I(p, k, ch, r, clamp_side=cs, num=num)
    plt.plot(set_vh, (set_vh+meas_vh), label="CL%s_U @ %s #%i" % (cs, r, (i*2)+1))

    # r = "200u"
    # set_vh ,meas_vh = pmu_cal.measureCL_I(p, k, ch, r, clamp_side=cs, num=num)
    # plt.plot(set_vh, (set_vh+meas_vh), label="CLH_U @ %s #1" % (r))

plt.title("Force-V - I-Clamp - CH%i" % ch)
plt.xlabel("Set_I [A]")
plt.ylabel("Error")
plt.legend()
plt.grid()

plt.show()
# Out:
# CLL_I_M CALIBRATION for channel 0 @ 2mA
# 	NEW_CLL_I_M = CLL_I_M * ((I_HIGH_SET / I_HIGH_MEAS) + 1) / 2
# 	63358 = 65534 * ((-2.228 mA / -2.386 mA) + 1) / 2
# 	I_MAX after Cal = -2.386 mA
# CLL_I_C CALIBRATION for channel 0 @ 2mA
# 	NEW_CLL_I_C = CLL_I_C - (Zero_offset / LSB)
# 	35735 = 32768 - (-201.663 µA / 67.978 nA)
# 	Offset after Cal = 3.055 µA
# CLL_I_M CALIBRATION for channel 0 @ 2mA
# 	NEW_CLL_I_M = CLL_I_M * ((I_HIGH_SET / I_HIGH_MEAS) + 1) / 2
# 	64029 = 63358 * ((-2.228 mA / -2.181 mA) + 1) / 2
# 	I_MAX after Cal = -2.181 mA
# CLL_I_C CALIBRATION for channel 0 @ 2mA
# 	NEW_CLL_I_C = CLL_I_C - (Zero_offset / LSB)
# 	35350 = 35735 - (26.185 µA / 67.978 nA)
# 	Offset after Cal = -384.931 nA
# CLL_I_M CALIBRATION for channel 0 @ 2mA
# 	NEW_CLL_I_M = CLL_I_M * ((I_HIGH_SET / I_HIGH_MEAS) + 1) / 2
# 	64312 = 64028 * ((-2.228 mA / -2.208 mA) + 1) / 2
# 	I_MAX after Cal = -2.208 mA
# CLL_I_C CALIBRATION for channel 0 @ 2mA
# 	NEW_CLL_I_C = CLL_I_C - (Zero_offset / LSB)
# 	35211 = 35350 - (9.420 µA / 67.978 nA)
# 	Offset after Cal = -177.324 nA

# %%
k.play_chord(notes=("F#5", "G#5", "A5", "B5", "C#5", "D5", "E5"), durations=0.1)
k.display.screen = k.display.USER
k.display.clear()
k.display.settext("$BDONE$N")
# p.reset()
